# %% [markdown]
# ### Что изменено?
# - Аналогичные лабе 2 изменения (чуть более слабая модель, [немного промпт-инженеринга](https://www.youtube.com/watch?v=Va4_6QtKAwQ))
# - Регулируемое число примеров для few-shot промпта
# - Для каждого ответа с категорией, которой нет в списке, делаем ещё один запрос модели, чтобы она попробовала уточнить категорию самостоятельно
# - **Просить модель сперва обосновать ход "мыслей", а затем дать ответ на основе рассуждений**

# %%
# !pip install datasets -q
# !pip install transformers -q
# !pip install accelerate -q
# !pip install fuzzywuzzy -q
# !pip install python-Levenshtein -q

# https://stackoverflow.com/questions/53247985/tqdm-4-28-1-in-jupyter-notebook-intprogress-not-found-please-update-jupyter-an
# !pip install ipywidgets -q
# !pip install jupyterlab -q

# %%
from typing import Dict, List, Union

import datasets
import transformers

from fuzzywuzzy import fuzz, process

import sklearn.metrics as m
from tqdm.notebook import tqdm
import random

# %% [markdown]
# ### Функция для создания промптов к модели
#
# **[Здесь и находится ключевое отличие few-shot подхода от zero-shot](https://courses.sberuniversity.ru/llm-gigachat/2/3/2)**

# %%
def prepare_message_for_llm(
        text: Union[str, List[str]],
        examples: Dict[str, List[str]],
        prompt_system: str,
        prompt_user: str
    ) -> Dict[str, Union[List[Dict[str, str]], List[List[Dict[str, str]]]]]:

    assert len(examples) >= 2, f'Ожидалось 2+ категорий, получено {len(examples)}'

    categories = list(examples.keys())
    categories_as_string = '; '.join(categories)
    # print(examples, categories)

    prompt_user_full = f'{prompt_user}'

    for category in categories:
        if (len(examples[category]) > 0):
            for example in examples[category]:
                prompt_user_full += f'\nПРИМЕР: {example} ' \
                                    f'\nОТВЕТ: {category} '
            # prompt += f'Текст: {" ".join(examples[cur].split())}\nВаш ответ: {cur}\n'

    prompt_user_full += f'\nЗАДАНИЕ: {text} \nСПИСОК ТЕМ (выберите ОДНУ тему СТРОГО ' \
                        f'из этого списка): "{categories_as_string}" \nВАШ ОТВЕТ: '

    messages = [
        {
            'role': 'system',
            'content': prompt_system
        },
        {
            'role': 'user',
            'content': prompt_user_full
        }
    ]

    return {'message_for_llm': messages}

# %% [markdown]
# # Pipeline
#
# ### Загрузим модель

# %%
try:
    print(LLM_PIPELINE)
except:
    LLM_PIPELINE = transformers.pipeline(model='Qwen/Qwen2.5-3B-Instruct', device_map='cuda:0', torch_dtype='auto')
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Загрузим датасет

# %%
DATASET_NAME = 'Davlan/sib200'
DATASET_LANGUAGE = 'rus_Cyrl'
train_set = datasets.load_dataset(DATASET_NAME, DATASET_LANGUAGE, split='train')
validation_set = datasets.load_dataset(DATASET_NAME, DATASET_LANGUAGE, split='validation')
test_set = datasets.load_dataset(DATASET_NAME, DATASET_LANGUAGE, split='test')

# %% [markdown]
# ### Выделим категории

# %%
list_of_categories = sorted(list(
    set(train_set['category']) | set(validation_set['category']) | set(test_set['category'])
))
print(f'Категории классификации текстов: \n{list_of_categories}')
# Out:
# Категории классификации текстов:
# ['entertainment', 'geography', 'health', 'politics', 'science/technology', 'sports', 'travel']

# %%
print(validation_set)
# Out:
# Dataset({
#     features: ['index_id', 'category', 'text'],
#     num_rows: 99
# })

# %% [markdown]
# ### Выделим случайные примеры
#
# Тут добавил фичу чтобы менять число примеров, начиная с 3 примеров она или почти не влияет или вообще ухудшает

# %%
amount_of_examples = 2
random.seed(2024)

examples_by_categories = dict()

for current_category in list_of_categories:
    category_examples = []

    for ex_no in range(amount_of_examples):
        category_examples.append(
            random.choice(
                train_set.filter(lambda it: it['category'] == current_category)['text']
            )
        )

    examples_by_categories[current_category] = category_examples
    print(f'Категория: "{current_category}" \n{examples_by_categories[current_category]}\n')
# Out:
# Категория: "entertainment"
# ['Это когда люди посещают место, которое очень отличается от их обычной повседневной жизни, чтобы расслабиться и развлечься.', 'Вечер начал певец Санджу Шарма, за ним выступил Джай Шанкар Чаудхари. esented the chhappan bhog bhajan также. Ему аккомпанировал певец Раджу Кханделвал.']
#
# Категория: "geography"
# ['Пятнадцать из этих метеоритов связывают с метеоритным дождем, прошедшим в июле прошлого года.', 'Некогда древний город Смирна сегодня — современный, развитый и оживленный торговый центр, расположившийся вдоль огромного залива и окруженный горами.']
#
# Категория: "health"
# ['Тем, кто тренируется постоянно, требуется больше поддержки по причине негативного отношения к боли и для того, чтобы отличить хронические боли от чувства дискомфорта после обычных физических нагрузок.', 'Они научились мастерски делать ампутации, чтобы спасать пациентов от гангрены, и так же хорошо освоили жгут и артериальные зажимы для приостановки кровотока.']
#
# Категория: "politics"
# ['Администратор Commons Адам Керден выразил своё разочарование в связи с удалениями в своем разговоре  в прошлом месяце с Wikinews.', 'Вчера Мартейи привёл к присяге новый Временный избирательный совет (ВИС), состоящий из девяти участников.']
#
# Категория: "science/technology"
# ['На следующем изображении показаны атомы, излучающие фотоны. Конечно, в действительности фотоны намного меньше, чем те, которые изображены на картинке.', 'Использование Интернета и Всемирной паутины позволяет учащимся иметь доступ к информации в любой момент.']
#
# Категория: "sports"
# ['Первая голевая передача Овечкина в тот вечер принесла команде победный гол, выполненный новичком Никласом Бекстрёмом;', 'Итальянская сборная по футболу, наряду с немецкой, является второй самой успешной командой в мире и в 2006 году выиграла Кубок мира ФИФА.']
#
# Категория: "travel"
# ['Если на страну, которую вы собираетесь посетить, распространяются  рекомендации с предупреждением об опасности их посещения, то это может повлиять на вашу медицинскую страховку во время поездки или на вашу страховку от отмены поездки.', 'Путешествуя впервые по одной из развивающихся стран или попадая в ту часть света, где вы раньше не бывали, будьте готовы в возможному сильному  культурному потрясению.']

# %% [markdown]
# ### Обернём тексты в prompt для llm

# %%
# prompt_system_1 = 'Вы — умный помощник, умеющий читать и анализировать тексты ' \
#                   'на русском языке, всегда дающий продуманные верные ответы. '

# prompt_user_1 = 'Прочтите, пожалуйста, следующий набор текстов ниже ' \
#                 'и определите, какая ОДНА тема из списка тем внизу ' \
#                 'НАИБОЛЕЕ представлена. В ответ напишите ОДНУ НАИБОЛЕЕ' \
#                 'подходящую тему из списка, больше ничего. Спасибо! '

# %%
prompt_system_1 = 'Вы — очень рассудительный ассистент, умеющий детально ' \
                  'и подробно анализировать тексты на русском языке, ' \
                  'беспрекословно дающий продуманные верные ответы. '

prompt_user_1 = 'Прочтите, пожалуйста, следующий набор текстов ниже ' \
                'и определите, какая ОДНА тема из списка тем внизу ' \
                'НАИБОЛЕЕ представлена. Вы должны выбрать ТОЛЬКО ОДНУ, ' \
                'НАИБОЛЕЕ подходящую тему, взятую СТРОГО ИЗ СПИСКА. ' \
                'В ответ сперва напишите ваш процесс рассуждения, затем ' \
                'ДВА "\n", а затем, ОДНИМ СЛОВОМ, выбранная вами тема. '

# %%
validation_set_for_llm = validation_set.map(
    lambda it: prepare_message_for_llm(
        it['text'],
        examples_by_categories,
        prompt_system_1,
        prompt_user_1
    )
)

# %%
print(validation_set_for_llm)
# Out:
# Dataset({
#     features: ['index_id', 'category', 'text', 'message_for_llm'],
#     num_rows: 99
# })

# %%
print(validation_set_for_llm['message_for_llm'][0])
# Out:
# [{'content': 'Вы — очень рассудительный ассистент, умеющий детально и подробно анализировать тексты на русском языке, беспрекословно дающий продуманные верные ответы. ', 'role': 'system'}, {'content': 'Прочтите, пожалуйста, следующий набор текстов ниже и определите, какая ОДНА тема из списка тем внизу НАИБОЛЕЕ представлена. Вы должны выбрать ТОЛЬКО ОДНУ, НАИБОЛЕЕ подходящую тему, взятую СТРОГО ИЗ СПИСКА. В ответ сперва напишите ваш процесс рассуждения, затем ДВА "\n", а затем, ОДНИМ СЛОВОМ, выбранная вами тема. \nПРИМЕР: Это когда люди посещают место, которое очень отличается от их обычной повседневной жизни, чтобы расслабиться и развлечься. \nОТВЕТ: entertainment \nПРИМЕР: Вечер начал певец Санджу Шарма, за ним выступил Джай Шанкар Чаудхари. esented the chhappan bhog bhajan также. Ему аккомпанировал певец Раджу Кханделвал. \nОТВЕТ: entertainment \nПРИМЕР: Пятнадцать из этих метеоритов связывают с метеоритным дождем, прошедшим в июле прошлого года. \nОТВЕТ: geography \nПРИМЕР: Некогда древний город Смирна сегодня — современный, развитый и оживленный торговый центр, расположившийся вдоль огромного залива и окруженный горами. \nОТВЕТ: geography \nПРИМЕР: Тем, кто тренируется постоянно, требуется больше поддержки по причине негативного отношения к боли и для того, чтобы отличить хронические боли от чувства дискомфорта после обычных физических нагрузок. \nОТВЕТ: health \nПРИМЕР: Они научились мастерски делать ампутации, чтобы спасать пациентов от гангрены, и так же хорошо освоили жгут и артериальные зажимы для приостановки кровотока. \nОТВЕТ: health \nПРИМЕР: Администратор Commons Адам Керден выразил своё разочарование в связи с удалениями в своем разговоре  в прошлом месяце с Wikinews. \nОТВЕТ: politics \nПРИМЕР: Вчера Мартейи привёл к присяге новый Временный избирательный совет (ВИС), состоящий из девяти участников. \nОТВЕТ: politics \nПРИМЕР: На следующем изображении показаны атомы, излучающие фотоны. Конечно, в действительности фотоны намного меньше, чем те, которые изображены на картинке. \nОТВЕТ: science/technology \nПРИМЕР: Использование Интернета и Всемирной паутины позволяет учащимся иметь доступ к информации в любой момент. \nОТВЕТ: science/technology \nПРИМЕР: Первая голевая передача Овечкина в тот вечер принесла команде победный гол, выполненный новичком Никласом Бекстрёмом; \nОТВЕТ: sports \nПРИМЕР: Итальянская сборная по футболу, наряду с немецкой, является второй самой успешной командой в мире и в 2006 году выиграла Кубок мира ФИФА. \nОТВЕТ: sports \nПРИМЕР: Если на страну, которую вы собираетесь посетить, распространяются  рекомендации с предупреждением об опасности их посещения, то это может повлиять на вашу медицинскую страховку во время поездки или на вашу страховку от отмены поездки. \nОТВЕТ: travel \nПРИМЕР: Путешествуя впервые по одной из развивающихся стран или попадая в ту часть света, где вы раньше не бывали, будьте готовы в возможному сильному  культурному потрясению. \nОТВЕТ: travel \nЗАДАНИЕ: Если увеличить расстояние для бега с четверти до половины мили, скорость становится не так важна, тогда как выносливость превращается в абсолютную необходимость. \nСПИСОК ТЕМ (выберите ОДНУ тему СТРОГО из этого списка): "entertainment; geography; health; politics; science/technology; sports; travel" \nВАШ ОТВЕТ: ', 'role': 'user'}]

# %% [markdown]
# ### Сгенерируем ответы

# %%
print(
    LLM_PIPELINE(validation_set_for_llm['message_for_llm'][60], max_new_tokens=200)[0]['generated_text']
)
print(
    LLM_PIPELINE(validation_set_for_llm['message_for_llm'][60], max_new_tokens=200)[0]['generated_text'][-1]['content'].strip(' \n."').split(' ')[-1].strip(' \n."')
)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# [{'content': 'Вы — очень рассудительный ассистент, умеющий детально и подробно анализировать тексты на русском языке, беспрекословно дающий продуманные верные ответы. ', 'role': 'system'}, {'content': 'Прочтите, пожалуйста, следующий набор текстов ниже и определите, какая ОДНА тема из списка тем внизу НАИБОЛЕЕ представлена. Вы должны выбрать ТОЛЬКО ОДНУ, НАИБОЛЕЕ подходящую тему, взятую СТРОГО ИЗ СПИСКА. В ответ сперва напишите ваш процесс рассуждения, затем ДВА "\n", а затем, ОДНИМ СЛОВОМ, выбранная вами тема. \nПРИМЕР: Это когда люди посещают место, которое очень отличается от их обычной повседневной жизни, чтобы расслабиться и развлечься. \nОТВЕТ: entertainment \nПРИМЕР: Вечер начал певец Санджу Шарма, за ним выступил Джай Шанкар Чаудхари. esented the chhappan bhog bhajan также. Ему аккомпанировал певец Раджу Кханделвал. \nОТВЕТ: entertainment \nПРИМЕР: Пятнадцать из этих метеоритов связывают с метеоритным дождем, прошедшим в июле прошлого года. \nОТВЕТ: geography \nПРИМЕР: Некогда древний город Смирна сегодня — современный, развитый и оживленный торговый центр, расположившийся вдоль огромного залива и окруженный горами. \nОТВЕТ: geography \nПРИМЕР: Тем, кто тренируется постоянно, требуется больше поддержки по причине негативного отношения к боли и для того, чтобы отличить хронические боли от чувства дискомфорта после обычных физических нагрузок. \nОТВЕТ: health \nПРИМЕР: Они научились мастерски делать ампутации, чтобы спасать пациентов от гангрены, и так же хорошо освоили жгут и артериальные зажимы для приостановки кровотока. \nОТВЕТ: health \nПРИМЕР: Администратор Commons Адам Керден выразил своё разочарование в связи с удалениями в своем разговоре  в прошлом месяце с Wikinews. \nОТВЕТ: politics \nПРИМЕР: Вчера Мартейи привёл к присяге новый Временный избирательный совет (ВИС), состоящий из девяти участников. \nОТВЕТ: politics \nПРИМЕР: На следующем изображении показаны атомы, излучающие фотоны. Конечно, в действительности фотоны намного меньше, чем те, которые изображены на картинке. \nОТВЕТ: science/technology \nПРИМЕР: Использование Интернета и Всемирной паутины позволяет учащимся иметь доступ к информации в любой момент. \nОТВЕТ: science/technology \nПРИМЕР: Первая голевая передача Овечкина в тот вечер принесла команде победный гол, выполненный новичком Никласом Бекстрёмом; \nОТВЕТ: sports \nПРИМЕР: Итальянская сборная по футболу, наряду с немецкой, является второй самой успешной командой в мире и в 2006 году выиграла Кубок мира ФИФА. \nОТВЕТ: sports \nПРИМЕР: Если на страну, которую вы собираетесь посетить, распространяются  рекомендации с предупреждением об опасности их посещения, то это может повлиять на вашу медицинскую страховку во время поездки или на вашу страховку от отмены поездки. \nОТВЕТ: travel \nПРИМЕР: Путешествуя впервые по одной из развивающихся стран или попадая в ту часть света, где вы раньше не бывали, будьте готовы в возможному сильному  культурному потрясению. \nОТВЕТ: travel \nЗАДАНИЕ: Архипелаг располагается в 120 километрах от полуострова. Крупнейшим остров носит имя Короля Георга с поселением Вилья-лас-Эстрельяс. \nСПИСОК ТЕМ (выберите ОДНУ тему СТРОГО из этого списка): "entertainment; geography; health; politics; science/technology; sports; travel" \nВАШ ОТВЕТ: ', 'role': 'user'}, {'role': 'assistant', 'content': 'Процесс рассуждения:\nВ данном тексте речь идет о расположении архипелага относительно полуострова и о названии крупнейшего острова в архипелаге. Эти факты указывают на географическую информацию, связанную с местностью.\n\nВыбранная тема:\ngeography'}]
# geography

# %%
validation_pred = list(map(
    lambda x: LLM_PIPELINE(x, max_new_tokens=200)[0]['generated_text'],
    tqdm(validation_set_for_llm['message_for_llm'])
))
validation_true = validation_set['category']
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
print(validation_pred[1])
# Out:
# [{'content': 'Вы — очень рассудительный ассистент, умеющий детально и подробно анализировать тексты на русском языке, беспрекословно дающий продуманные верные ответы. ', 'role': 'system'}, {'content': 'Прочтите, пожалуйста, следующий набор текстов ниже и определите, какая ОДНА тема из списка тем внизу НАИБОЛЕЕ представлена. Вы должны выбрать ТОЛЬКО ОДНУ, НАИБОЛЕЕ подходящую тему, взятую СТРОГО ИЗ СПИСКА. В ответ сперва напишите ваш процесс рассуждения, затем ДВА "\n", а затем, ОДНИМ СЛОВОМ, выбранная вами тема. \nПРИМЕР: Это когда люди посещают место, которое очень отличается от их обычной повседневной жизни, чтобы расслабиться и развлечься. \nОТВЕТ: entertainment \nПРИМЕР: Вечер начал певец Санджу Шарма, за ним выступил Джай Шанкар Чаудхари. esented the chhappan bhog bhajan также. Ему аккомпанировал певец Раджу Кханделвал. \nОТВЕТ: entertainment \nПРИМЕР: Пятнадцать из этих метеоритов связывают с метеоритным дождем, прошедшим в июле прошлого года. \nОТВЕТ: geography \nПРИМЕР: Некогда древний город Смирна сегодня — современный, развитый и оживленный торговый центр, расположившийся вдоль огромного залива и окруженный горами. \nОТВЕТ: geography \nПРИМЕР: Тем, кто тренируется постоянно, требуется больше поддержки по причине негативного отношения к боли и для того, чтобы отличить хронические боли от чувства дискомфорта после обычных физических нагрузок. \nОТВЕТ: health \nПРИМЕР: Они научились мастерски делать ампутации, чтобы спасать пациентов от гангрены, и так же хорошо освоили жгут и артериальные зажимы для приостановки кровотока. \nОТВЕТ: health \nПРИМЕР: Администратор Commons Адам Керден выразил своё разочарование в связи с удалениями в своем разговоре  в прошлом месяце с Wikinews. \nОТВЕТ: politics \nПРИМЕР: Вчера Мартейи привёл к присяге новый Временный избирательный совет (ВИС), состоящий из девяти участников. \nОТВЕТ: politics \nПРИМЕР: На следующем изображении показаны атомы, излучающие фотоны. Конечно, в действительности фотоны намного меньше, чем те, которые изображены на картинке. \nОТВЕТ: science/technology \nПРИМЕР: Использование Интернета и Всемирной паутины позволяет учащимся иметь доступ к информации в любой момент. \nОТВЕТ: science/technology \nПРИМЕР: Первая голевая передача Овечкина в тот вечер принесла команде победный гол, выполненный новичком Никласом Бекстрёмом; \nОТВЕТ: sports \nПРИМЕР: Итальянская сборная по футболу, наряду с немецкой, является второй самой успешной командой в мире и в 2006 году выиграла Кубок мира ФИФА. \nОТВЕТ: sports \nПРИМЕР: Если на страну, которую вы собираетесь посетить, распространяются  рекомендации с предупреждением об опасности их посещения, то это может повлиять на вашу медицинскую страховку во время поездки или на вашу страховку от отмены поездки. \nОТВЕТ: travel \nПРИМЕР: Путешествуя впервые по одной из развивающихся стран или попадая в ту часть света, где вы раньше не бывали, будьте готовы в возможному сильному  культурному потрясению. \nОТВЕТ: travel \nЗАДАНИЕ: Посмотрите, какие поездки рекламирует агент, на сайте или на витрине офиса. \nСПИСОК ТЕМ (выберите ОДНУ тему СТРОГО из этого списка): "entertainment; geography; health; politics; science/technology; sports; travel" \nВАШ ОТВЕТ: ', 'role': 'user'}, {'role': 'assistant', 'content': 'Процесс рассуждения: В данном тексте говорится о рекламе поездок. Это может относиться к различным направлениям, но основное внимание здесь уделяется предложению услуг для путешественников.\n\nОТВЕТ: travel'}]

# %%
print(m.classification_report(
    y_true=validation_true,
    y_pred=[x[-1]['content'].strip('.,:\'"* \n').split(' ')[-1].strip('.,:\'"* \n') for x in validation_pred])
)
# Out:
#                             precision    recall  f1-score   support
#
#              (путешествие)       0.00      0.00      0.00         0
#              entertainment       0.67      0.44      0.53         9
#                  geography       0.56      0.62      0.59         8
#                     health       0.86      0.55      0.67        11
#           history
#
# history       0.00      0.00      0.00         0
#                   politics       0.91      0.71      0.80        14
#         science/technology       0.81      0.68      0.74        25
#                     sports       1.00      0.50      0.67        12
#                     travel       0.68      0.65      0.67        20
#                          О       0.00      0.00      0.00         0
#             будет:
#
# travel       0.00      0.00      0.00         0
# выбор:
#
# science/technology       0.00      0.00      0.00         0
#                          г       0.00      0.00      0.00         0
#                        или       0.00      0.00      0.00         0
#           инфраструктурных       0.00      0.00      0.00         0
#               медицинскими       0.00      0.00      0.00         0
#                         не       0.00      0.00      0.00         0
#                          о       0.00      0.00      0.00         0
#  ответ:
# science/technology       0.00      0.00      0.00         0
#                      прямо       0.00      0.00      0.00         0
#             спорт.
#
# sports       0.00      0.00      0.00         0
#   тема:
# science/technology       0.00      0.00      0.00         0
#               тема:
# sports       0.00      0.00      0.00         0
#               тема:
# travel       0.00      0.00      0.00         0
#   темы:
# science/technology       0.00      0.00      0.00         0
#
#                   accuracy                           0.62        99
#                  macro avg       0.22      0.17      0.19        99
#               weighted avg       0.79      0.62      0.69        99

# %% [markdown]
# ### Находим некорректные ответы

# %%
validation_clarification_idx = []
validation_clarification_set = []

for i, conversation in enumerate(validation_pred):
    for entry in conversation:
        if entry['role'] == 'assistant' and entry['content'] not in list_of_categories:
            validation_clarification_idx.append(i)

# %%
print(f'Ответы с выдуманными категориями ({len(validation_clarification_idx)}):')

for i in validation_clarification_idx:
    validation_clarification_entry = validation_set[i]
    validation_clarification_entry['text'] #+= f' (неверая тема: {validation_pred[i][-1]["content"]})'
    validation_clarification_set.append(validation_clarification_entry)
    
    print(f'№{int(i)} -- {validation_pred[i][-1]["content"]} ({validation_set[i]})')
# Out:
# Ответы с выдуманными категориями (99):
# №0 -- Приступим к анализу текста: "Если увеличить расстояние для бега с четверти до половины мили, скорость становится не так важна, тогда как выносливость превращается в абсолютную необходимость."
#
# Этот текст подчеркивает важность выносливости в условиях усиленной тренировки. Он не прямо говорит о развлечениях, местоположении, здоровье, политике, науке/технологии или спорте. Тема путешествий здесь не обозначена.
#
# Тема, которая наиболее точно соответствует содержанию данного текста - это "health" (здоровье).
#
# Ваш выбор: health ({'index_id': 548, 'category': 'sports', 'text': 'Если увеличить расстояние для бега с четверти до половины мили, скорость становится не так важна, тогда как выносливость превращается в абсолютную необходимость.'})
# №1 -- Процесс рассуждения:
# В данном тексте говорится о рекламе различных поездок. Название "поездки" указывает на туризм, путешествия. Также в контексте рекламы часто используются термины, связанные с туризмом, например, "отдых", "курорт", "для активного отдыха". Однако основное содержание текста - это информация о предлагаемых турах, что подчеркивает туризм и путешествия.
#
# Выбранная тема:
# travel ({'index_id': 824, 'category': 'travel', 'text': 'Посмотрите, какие поездки рекламирует агент, на сайте или на витрине офиса.'})
# №2 -- Процесс рассуждения:
# 1. Текст рассматривает факты об inhabitant (население) и characteristics (особенности) Ватикана.
# 2. Основное внимание уделяется размеру населения и его независимости.
# 3. Тема не касается культуры, спорта, технологий, медицины, политики или развлечений.
# 4. Текст не содержит элементов путешествия или туризма.
# Выбранная тема: geography ({'index_id': 1628, 'category': 'geography', 'text': 'Население Ватикана составляет около 800 человек. Это самая маленькая независимая страна в мире, а также страна, имеющая наименьшее население.'})
# №3 -- Процесс рассуждения:
# В данном тексте речь идет о научном эксперименте, который предполагает важную роль ДНК в генетике. Этот эксперимент был ключевым шагом в понимании роли ДНК в генетике организма. Таким образом, основное внимание в тексте уделяется научному исследованию.
#
# Выбранная тема: science/technology
#
# ВЫБРАННАЯ ТЕМА: science/technology ({'index_id': 1596, 'category': 'science/technology', 'text': 'Эксперимент  Херши и Чейз был одним из первых предположений, что ДНК является генетическим материалом.'})
# №4 -- Процесс рассуждения:
# В данном тексте речь идет о островном государстве Острова Кука, его статусе в качестве свободной ассоциации с Новой Зеландией, местоположении в Полинезии и в центре южной части Тихого океана. Эти факты представляют собой географическую информацию о месте, которое описывается.
#
# Выбранная тема: geography ({'index_id': 739, 'category': 'geography', 'text': 'Острова Кука – это островное государство, состоящее в свободной ассоциации с Новой Зеландией, находящейся в Полинезии в центре южной части Тихого океана.'})
# №5 -- Процесс рассуждения:
# В данном тексте речь идет о том, как научиться бросать бумеранг, который возвращается вам в руки. Для этого важно наличие подходящего бумеранга. Это не относится к развлекательным мероприятиям, не к вопросам географии, не к вопросам здоровья, не к политическим событиям, не к науке и технологиям, не к спорту. Это касается именно инструмента, который используется для развлечений или занятий.
#
# Выбранная тема:
# travel ({'index_id': 847, 'category': 'entertainment', 'text': 'Если вы хотите научиться бросать бумеранг, который возвращается вам в руки, убедитесь, что у вас есть подходящий для возвращения бумеранг.'})
# №6 -- Процесс рассуждения: В данном тексте речь идет о истории возникновения горнолыжного спорта. Особое внимание уделяется его происхождению и первому развлекательному лыжному клубу в Австралии в 1861 году. Это указывает на то, что основная тема здесь связана с историей спорта и его развития.
#
# Выбранная тема: sports ({'index_id': 1849, 'category': 'sports', 'text': 'Горнолыжный спорт как вид спорта восходит по крайней мере к XVII веку, а в 1861 году норвежцы открыли первый развлекательный лыжный клуб в Австралии.'})
# №7 -- Процесс рассуждения:
# Текст описывает достопримечательность Южной Африки и ее статус среди национальных парков страны. Это указывает на то, что речь идет о месте или объекте, который имеет историческую или культурную значимость.
#
# Выбранная тема: geography ({'index_id': 1721, 'category': 'travel', 'text': 'Он является одной из главных достопримечательностей Южной Африки и считается ведущим среди южноафриканских национальных парков (SANParks).'})
# №8 -- Процесс рассуждения:
# 1. В тексте говорится о записи музыки с использованием современных компьютеров.
# 2. Это не относится к развлекательным мероприятиям (entertainment).
# 3. Не касается географии (geography).
# 4. Не связано со здоровьем (health).
# 5. Не имеет политического аспекта (politics).
# 6. Не касается спорта (sports).
# 7. Не касается путешествий (travel).
#
# Поэтому данное высказывание наиболее точно соответствует теме "science/technology".
#
# ДВА ""
# science/technology ({'index_id': 612, 'category': 'science/technology', 'text': 'Музыка часто записывается с помощью современных компьютеров, обрабатывающих и смешивающих звуки.'})
# №9 -- Процесс анализа:
# 1. В тексте говорится о связи между автомобилями и развитием дорог.
# 2. Этот контекст не относится ни к развлечениям, ни к географии, ни к здоровью, ни к политике, ни к науке и технологиям, ни к спорту.
# 3. Однако, данный текст может быть связан с путешествиями, если рассматривать развитие дорожной сети как фактор влияющий на развитие страны и культуру местного населения.
#
# Выбранная тема: travel ({'index_id': 1480, 'category': 'science/technology', 'text': 'Например, можно было бы сказать, что автомобиль является обязательной причиной развития дорог.'})
# №10 -- Процесс рассуждения:
# В данном тексте речь идет о действиях по перекрытию входов в метро. Это явно относится к сфере городского управления и безопасности. Тема "politics" кажется наиболее подходящей, поскольку политика и безопасность включают в себя такие вопросы.
#
# Выбранная тема: politics
#
# ", politics ({'index_id': 259, 'category': 'travel', 'text': 'Для перекрытия входов в метро были использованы самосвалы, а подмога из 80 полицейских направляла автомобилистов в объезд.'})
# №11 -- Процесс рассуждения:
# 1. Тема "travel" не подходит, так как исследование происходит в южноафриканском регионе, а не путешествие.
# 2. Тема "geography" тоже не подходит, так как речь идет о науке и исследованиях, а не о географических характеристиках региона.
# 3. Тема "health" не подходит, хотя упоминается туберкулез, но исследование не направлено на лечение или медицинские аспекты, а на открытие нового типа туберкулеза.
# 4. Тема "politics" не подходит, так как нет никаких политических элементов в данном тексте.
# 5. Тема "science/technology" не подходит, так как речь идет о науке, а не о технологиях.
# 6. Тема ({'index_id': 1094, 'category': 'health', 'text': 'В ходе исследований в южноафриканском регионе Квазулу-Натал доктору Тони Моллу (Tony Moll ) удалось обнаружить туберкулез с исключительно высокой устойчивостью к лекарствам (XDR-TB).'})
# №12 -- Процесс рассуждения:
# 1. Текст описывает конкретную операцию в военном контексте, включающую движение ополченцев и контроль над мостом.
# 2. Этот текст не связан ни с развлечениями, ни с наукой и технологиями, ни с здоровьем, ни с политическими событиями.
# 3. Тема "туризма" (travel) здесь не применима, так как речь идет о военных действиях, а не о поездках и путешествиях.
# 4. Тема "географии" (geography) тоже не соответствует, так как текст не затрагивает местоположение или картографические вопросы.
# 5. Тема "политики" (politics) не применима, так как речь идет о военных действиях и операциях, а не о политических ({'index_id': 546, 'category': 'politics', 'text': 'Генерал Джеймс Эвинг (James Ewing) поведет 700 ополченцев на другой берег реки у Трентон-Ферри, возьмет под свой контроль мост через Ассунпинк-Крик и воспрепятствует отступлению вражеских войск.'})
# №13 -- Приступим к анализу текста: "Термин "сафари" в повседневном использовании означает наземную поездку с целью посмотреть поразительную дикую природу Африки, особенно в саванне."
#
# Ответ: travel ({'index_id': 1805, 'category': 'travel', 'text': 'Термин "сафари" в повседневном использовании означает наземную поездку с целью посмотреть поразительную дикую природу Африки, особенно в саванне.'})
# №14 -- Процесс рассуждения: В данном тексте речь идет о двух классах пригородных поездов в Кейптауне. Это не относится к развлечениям, географии, здоровью, политике, науке/технологиям или спорту. Тема, которая наиболее подходяща для этого текста, - это "travel".
#
# Ответ: travel ({'index_id': 853, 'category': 'travel', 'text': 'В Кейптауне и его окрестностях есть два класса пригородных поездов MetroRail: "MetroPlus" (также именуемый первым классом) и "Metro" (третий класс).'})
# №15 -- Процесс рассуждения:
# В данном тексте рассматривается терминологическая информация - происхождение слова "клетка" от латинского "cella". Этот текст не имеет прямого отношения ни к развлечениям, ни к природе, ни к здоровью, ни к политическим вопросам, ни к спорту, ни к путешествиям. Он больше относится к лингвистической теме.
#
# Выбранная тема: science/technology ({'index_id': 596, 'category': 'science/technology', 'text': 'Слово "клетка" происходит от латинского слова cella, что значит маленькая комната.'})
# №16 -- Процесс рассуждения:
# 1. В данном тексте речь идет о нервной системе и ее функциях.
# 2. Нервная система поддерживает гомеостаз, что указывает на научную или медицинскую тему.
# 3. Гомеостаз - это баланс в организме, который поддерживается благодаря нервной системе.
# 4. Тема нервной системы и ее роли в поддержании баланса в организме соответствует области медицины или науки.
#
# Выбранная тема: health ({'index_id': 579, 'category': 'science/technology', 'text': 'Нервная система поддерживает гомеостаз, посылая нервные импульсы через все тело, чтобы поддерживать кровоток и не нарушать его.'})
# №17 -- Процесс рассуждения:
# 1. Текст рассматривает сплавы как смесь металлов.
# 2. Обсуждается периодическая таблица и элементы, что указывает на науку и технологии.
# 3. Нет явного упоминания культуры, путешествий, спорта или политики.
# 4. Текст не содержит элементов развлечений или медицинских аспектов.
#
# Выбранная тема: science/technology ({'index_id': 1635, 'category': 'science/technology', 'text': 'Сплавы по существу представляют собой смесь двух или более металлов. Не забывайте, что в периодической таблице много элементов.'})
# №18 -- Процесс рассуждения:
# В данном тексте речь идет о том, что первоначально шоу озвучивали актёры-любители из Восточного Техаса. В этом контексте не упоминается ни культура, ни медицинские аспекты, ни политические события, ни наука, ни спорт. Тема путешествий тоже не подходит, так как речь идет о шоу, а не о поездках. Поэтому остается только тема "entertainment", связанная с творческими мероприятиями.
#
# ОТВЕТ: entertainment ({'index_id': 1169, 'category': 'entertainment', 'text': 'Первоначально шоу озвучивали актёры-любители из Восточного Техаса.'})
# №19 -- Процесс рассуждения:
# 1. В данном тексте речь идет о новом штамме вируса, который вызывает высокий уровень смертности.
# 2. Тема охватывает медицинские аспекты и общественные вопросы безопасности.
# 3. Нет явного отсылания к культуру, географии, политическим вопросам, науке или спорту.
# 4. Тема путешествий также не прямо связана с данным сообщением.
#
# Выбранная тема: health ({'index_id': 1095, 'category': 'health', 'text': 'В интервью он сказал, что новый штамм "вызывает очень большие опасения, так как он приводит к очень высокому уровню смертности".'})
# №20 -- Процесс рассуждения:
# Текст говорит о том, что опрос показал определенное количество людей, которые поддерживают переход к последнему монарху. Это политический аспект, связан с управлением государством и изменениями в политической системе.
#
# Выбранная тема: politics
#
#  politics ({'index_id': 1321, 'category': 'politics', 'text': '34% опрошенных разделяют эту точку зрения и хотят, чтобы королева Елизавета II стала последним монархом Австралии.'})
# №21 -- Процесс рассуждения: В данном тексте речь идет о дневных походах, которые можно совершать пешком за один день. Это не относится к развлекательным мероприятиям, географическим особенностям, здоровью, политическим событиям, науке и технологиям или спорту. Тема путешествия также не прямо подразумевается.
#
# Выбранная тема: travel ({'index_id': 812, 'category': 'sports', 'text': 'Дневные походы выполняются на дистанции от менее мили, которые можно пройти пешком за день.'})
# №22 -- Приступим к анализу текста: "Горные зимние виды спорта, включающие в себя катание на лыжах и сноуборде, являются популярными видами спорта, которые подразумевают спуск по заснеженному рельефу на прикрепленных к ногам лыжах или сноуборде."
#
# Процесс рассуждения:
# 1. В тексте говорится о спортивных видах, связанных с катанием на лыжах и сноуборде.
# 2. Эти виды спорта связаны с зимними условиями (заснеженным рельефом).
# 3. Катание на лыжах и сноуборде - это явно виды спорта.
#
# Выбранная тема: sports ({'index_id': 1846, 'category': 'sports', 'text': 'Горные зимние виды спорта, включающие в себя катание на лыжах и сноуборде, являются популярными видами спорта, которые подразумевают спуск по заснеженному рельефу на прикрепленных к ногам лыжах или сноуборде.'})
# №23 -- Процесс рассуждения: В данном тексте речь идет о разделении, основанном на ископаемых материалах, и сравнении его с молекулярными данными. Этот текст не связан с развлечениями, географией, здоровьем, политицией, наукоемкими технологиями или спортом. Он касается научных исследований и открытий, что соответствует области науки и техники.
#
# Выбранная тема: science/technology
#
# ,science/technology ({'index_id': 143, 'category': 'science/technology', 'text': 'Судя по этим ископаемым, разделение произошло намного раньше, чем предполагалось на основании молекулярных сведений.'})
# №24 -- Процесс рассуждения:
# В данном тексте говорится о том, что при посещении Гренландии в холодное время года нужно взять теплую одежду. Этот текст не относится к сфере развлечений (entertainment), науке и технологиях (science/technology), здоровью (health), политике (politics), спорту (sports) или туризму (travel). Он касается конкретных рекомендаций по одежде в зависимости от местоположения и времени года.
#
# Выбранная тема: geography ({'index_id': 656, 'category': 'travel', 'text': 'Если вы посещаете Гренландию в холодное время года (учитывая, что чем севернее вы движетесь, тем становится холоднее), необходимо взять с собой достаточно теплую одежду.'})
# №25 -- Процесс рассуждения:
# В данном тексте говорится о том, как начать работу по написанию статей о путешествиях. Он не содержит никаких упоминаний касательно развлечений, географии, здоровья, политики, науки/технологий, спорта или туризма. Текст касается только метода написания статей о путешествиях.
#
# Выбранная тема: travel ({'index_id': 940, 'category': 'travel', 'text': 'Самый простой способ начать работу по написанию статей о путешествиях — это отточить свои навыки в уже существующем интернет-блоге о путешествиях.'})
# №26 -- Процесс рассуждения: В данном тексте речь идет о технических аспектах копирования данных на дисках. Он не затрагивает темы развлечений, географии, здоровья, политики, науки/технологий, спорта или путешествий. Этот текст касается вопросов технологий и копирования данных.
#
# Выбранная тема: science/technology
#
# ", science/technology ({'index_id': 909, 'category': 'science/technology', 'text': 'Фактически коды регионов не оказывают никакого эффекта на нелегальное копирование; побитная копия диска будет работать на любом устройстве, где будет работать оригинальный диск.'})
# №27 -- Процесс рассуждения:
# 1. Анализируем текст: "Переносчиками являются свиньи, от которых через комаров болезнь затем передаётся человеку."
# 2. Определяем ключевые слова и тематическую направленность:
#    - свиньи
#    - комары
#    - болезнь
#    - человек
# 3. Проверяем, соответствуют ли эти элементы темы из предоставленного списка.
# 4. Поиск совпадений:
#    - Свиньи и комары могут быть связаны с зоологией и экологией, что относится к теме "geography".
#    - Болезнь и человека также могут быть связаны с медициной и здоровьем, что относится к теме "health".
# 5. Из анализа видно, что термин "болезнь" указывает на ({'index_id': 1110, 'category': 'health', 'text': 'Переносчиками являются свиньи, от которых через комаров болезнь затем передаётся человеку.'})
# №28 -- Процесс рассуждения:
# В данном тексте упоминаются два аспекта: отсеки и изучение мёртвых клеток. Оба эти слова имеют отношение к науке и технологиям, поскольку исследования клеток обычно проводятся учеными и связаны с различными областями науки, включая биологию и медицину.
#
# Выбор темы:
# science/technology
#
# ВЫБРАННАЯ ТЕМА: science/technology ({'index_id': 599, 'category': 'science/technology', 'text': 'Они выглядели как отсеки. Он был первым, кто изучал мёртвые клетки.'})
# №29 -- Приступим к анализу текста:
# - Содержание текста - сообщение о том, что Пекин примет Олимпийские игры.
# - В контексте Олимпиады нет упоминания развлечений, здоровья, политики, науки, технологий или путешествий.
# - Текст не содержит информацию о географическом положении Пекина или о его культурных особенностях.
# - Текст не обсуждает медицинские аспекты подготовки к Олимпийским играм.
# - Текст не касается политической ситуации вокруг проведения игр или международных отношений.
# - Текст не обсуждает технологии или научные исследования, связанные с Олимпиадой.
# - Текст не касается путешествий или культурного опыта посещения Пекина.
# ОТВЕТ: sports ({'index_id': 766, 'category': 'sports', 'text': 'Столица Китая Пекин примет у себя зимние Олимпийские игры в 2022 году, что сделает его первым городом, принявшим у себя как летние, так и зимние Олимпийские игры.'})
# №30 -- Процесс рассуждения:
# 1. Текст рассматривает мост, его характеристики и функцию.
# 2. Основное внимание уделяется его местоположению (река, страны) и международному характеру.
# 3. Тема не связана ни с развлечениями, ни с здоровьем, ни с политическими событиями, ни с наукоемкими технологиями, ни с спортом.
# 4. Тема также не относится к путешествиям или туризму, так как речь идет о мосте, а не о поездке.
# Выбранная тема: geography ({'index_id': 1738, 'category': 'geography', 'text': "Мост через реку Ояпок представляет из себя вантовый мост. Он простирается через реку Ояпок и соединяет города Ояпоки в Бразилии и Сен-Жорж-де-л'Ояпок во Французской Гвиане."})
# №31 -- Процесс рассуждения:
# 1. Текст говорит о том, что большинство людей бронируют места заранее.
# 2. Это связано с сезонностью, когда места на лодках обычно заняты.
# 3. Это не имеет прямого отношения к разным областям знаний, таких как наука, технологии, медицина, политика, спорт или культура.
# 4. Тема не относится к путешествиям, так как речь идет о бронировании мест, а не о поездках.
# 5. Также это не относится к развлечениям, поскольку речь идет о бронировании, а не о том, что люди делают на месте.
# 6. Тема не касается здоровья или медицинских страховок.
# 7. Это не политическая тема, так как речь идет о бронировании мест ({'index_id': 713, 'category': 'travel', 'text': 'Большинство людей бронируют свои места заблаговременно (так как места на лодках обычно заняты в разгар сезона).'})
# №32 -- Процесс рассуждения:
# В данном тексте речь идет о специализированных жилых учреждениях для молодежи. Описание включает возрастные рамки гостей, а также упоминается возможность встречи путешественников постарше.
#
# Темы, которые могут быть связаны с этим текстом:
# - travel (поездка)
# - health (здоровье)
# - politics (политика)
# - science/technology (наука/технология)
#
# Тема travel наиболее подходяща, так как хостелы обычно являются средством для путешественников, особенно молодежи.
#
# ОТВЕТ: travel ({'index_id': 764, 'category': 'travel', 'text': 'Хостелы предназначены, главным образом, для молодых людей — возраст типичных гостей варьируется от двадцати до тридцати лет, но часто вы можете встретить там и путешественников постарше.'})
# №33 -- Приступая к анализу текста, мы видим, что речь идет о проведении ежегодного фестиваля в храмах. Этот фестиваль начинается с конца ноября и заканчивается в мае. Это явно связано с временными рамками и сезонностью, что указывает на тему "travel".
#
# ВАШ ОТВЕТ: travel ({'index_id': 769, 'category': 'entertainment', 'text': 'В большинстве храмов отмечается ежегодный фестиваль, проводящийся с конца ноября до середины мая. Даты проведения зависят от годового календаря каждого храма.'})
# №34 -- Процесс рассуждения:
# 1. Исследуем содержание текста: Ученые говорят о питании трицератопса, который относится к животным.
# 2. Сравниваем с предоставленными вариантами тем:
#    - entertainment: не связано с развлечениями;
#    - geography: не имеет отношения к географии;
#    - health: не касается здоровья;
#    - politics: не относится к политике;
#    - science/technology: не связано с наукою или технологиями;
#    - sports: не касается спорта;
#    - travel: не имеет отношение к путешествиям.
# 3. Оставшаяся тема - это "science/technology", которая относится к науке.
#
# ОТВЕТ: science/technology ({'index_id': 369, 'category': 'science/technology', 'text': 'Некоторые ученые полагают, что трицератопс питался саговниками — вид растений, который был распространен в меловом периоде.'})
# №35 -- Процесс рассуждения:
# В данном тексте речь идет о митингующих и полиции, а также о том, как они должны совмещать право на протест с безопасностью дорожного движения. Этот контекст более соответствует политической тематике, так как здесь затрагиваются права и ограничения граждан, а также действия государственных органов.
#
# Выбранная тема: politics ({'index_id': 9, 'category': 'politics', 'text': 'В 11:20 полиция попросила митингующих вернуться на тротуар, заявив, что им необходимо соблюдать баланс между правом протестовать и задержкой дорожного движения.'})
# №36 -- Процесс рассуждения: В данном тексте говорится о лыжных соревнованиях, которые пройдут в определенном горнолыжном районе. Этот текст не содержит элементов, относящихся к развлечениям, здоровью, политике, науке и технологиям, или спорту. Тема лыжных соревнований указывает на спорт, но основное внимание текста обращено на местоположение и расстояние до Пекина.
#
# Выбранная тема: travel ({'index_id': 768, 'category': 'sports', 'text': 'Другие лыжные соревнования пройдут в горнолыжном районе Тайцзичэн в Чжанцзякоу, примерно в 220 км (140 миль) от Пекина.'})
# №37 -- Процесс рассуждения: В данном тексте речь идет о необходимости прохождения профессиональной подготовки для тех, кто планирует посетить зону военных действий. Этот запрос связан с безопасностью и здоровьем путешественника. Тема путешествия и военные действия указывают на область "travel". Тема подготовки профессиональной подготовки также указывает на область "health".
#
# ОТВЕТ: travel ({'index_id': 1875, 'category': 'travel', 'text': 'Все, кто планирует посетить страну, которая может рассматриваться как зона военных действий, должны пройти профессиональную подготовку.'})
# №38 -- Процесс рассуждения:
# В данном тексте речь идет о беспилотном лунном орбитальном аппарате и его действиях. Описывается технологическое мероприятие, связанное с исследованием Луны, что соответствует области науки и технологий.
#
# Выбранная тема: science/technology
#
# **, science/technology** ({'index_id': 241, 'category': 'science/technology', 'text': 'Беспилотный лунный орбитальный аппарат "Чандраян-1" выбросил свой лунный ударный зонд (MIP), который пронёсся над поверхностью Луны со скоростью 1,5 километра в секунду (3000 миль в час), и успешно совершил жесткую посадку вблизи южного полюса Луны.'})
# №39 -- Процесс рассуждения:
# В данном тексте говорится о влиянии теплого климата на скорость роста и способность бактерий выживать вне организма. Это относится к вопросам здоровья и микробиологии, но не к любым из предоставленных тем.
#
# Выбранная тема:
# health ({'index_id': 863, 'category': 'health', 'text': 'Кроме того, в более теплом климате бактерии быстрее растут и дольше выживают вне организма.'})
# №40 -- Процесс рассуждения: В данном тексте речь идет о специализированных рейсах, которые отправляются по воздуху для альпинизма или походов к полюсу. Эти рейсы связаны с путешествием и исследованием местностей, что более соответствует теме "travel".
#
# ОТВЕТ: travel ({'index_id': 890, 'category': 'travel', 'text': 'Вглубь материка по воздуху отправляются нерегулярные специализированные рейсы, для альпинизма или походов к полюсу, где расположена крупная база.'})
# №41 -- Процесс рассуждения: В данном тексте речь идет о водорослях, которые вырабатывают нейротоксин, отключающий работу нервной системы у людей и рыб. Это явление связано с научными исследованиями и медициной, что соответствует теме "science/technology".
#
# Ответ: science/technology ({'index_id': 136, 'category': 'science/technology', 'text': 'Эти водоросли вырабатывают нейротоксин, который может отключить работу нервной системы как у людей, так и у рыб.'})
# №42 -- Процесс рассуждения: В данном тексте речь идет о событиях в истории древнего Китая, связанных с конфликтом за трон. Текст не содержит никаких ссылок на культуру, науку, спорт, политику, технологии или путешествия. Тема связана с историческими событиями и кровопролитием.
#
# Выбранная тема: history
#
# ", "history" ({'index_id': 1450, 'category': 'politics', 'text': 'Эпоха Троецарствия была одним из самых кровавых периодов в истории древнего Китая. Тысячи людей погибли, сражаясь за место на троне в большом дворце в Сиане.'})
# №43 -- Процесс рассуждения:
# 1. Текст говорит о визовых вопросах при посещении страны.
# 2. Он упоминает, что с 2009 года посещение берегов страны без отдельной визы возможно.
# 3. Этот контекст наиболее близок к теме путешествий и туризма.
#
# ОТВЕТ: travel ({'index_id': 1921, 'category': 'travel', 'text': 'Если вы сходите на берег только в порядке экскурсии на корабле, вам не понадобится отдельная виза (с 2009).'})
# №44 -- При чтении текста я заметила, что он связан с наукой и технологиями, поскольку речь идет о перьях птиц и их эволюции. Однако среди предоставленных тем именно "science/technology" наиболее точно соответствует содержанию данного текста.
#
# ВАШ ОТВЕТ: science/technology ({'index_id': 1026, 'category': 'science/technology', 'text': 'Находка также позволяет ознакомиться с эволюцией перьев у птиц.'})
# №45 -- Приступим к анализу текста:
# - В тексте упоминается "больница", что указывает на медицинскую тематику.
# - Слова "заболеть", "заразиться", "работник здравоохранения" также подчеркивают медицинский аспект.
#
# Тема health наиболее соответствует содержанию данного текста.
#
# health ({'index_id': 1096, 'category': 'health', 'text': 'Некоторые пациенты могли заразиться в больнице, думает доктор Молл, и по крайней мере двое были работниками здравоохранения в больнице.'})
# №46 -- Процесс рассуждения:
# В данном тексте речь идет о том, как путешественники адаптируются к новой культуре и стране. Это касается не только нового климата или новых ландшафтов (geography), не только здоровья (health), не только политической ситуации (politics) или технологий (science/technology), не только спорта (sports). Это касается процесса знакомства с новой культурой и обществом.
#
# Ответ: travel ({'index_id': 1893, 'category': 'travel', 'text': 'Когда вы вначале отправились за границу, люди, скорее всего, относились к вам с терпением и пониманием, зная, что путешественникам нужно адаптироваться в новой стране.'})
# №47 -- Процесс рассуждения:
# В данном тексте речь идет о меры безопасности, принятые после террористического акта. Этот акт произошел в США и был связан с безопасностью общества и воздушных перевозок. Тема безопасности и изменение мер безопасности после события соответствует теме "security/security measures". Однако среди предоставленного списка тем "security" не указано.
#
# Поскольку "security measures" не является включенным в список тем, а тема безопасности явно присутствует в тексте, мы будем выбирать наиболее подходящую из предложенных тем.
#
# Выбранное слово:
# travel ({'index_id': 1883, 'category': 'politics', 'text': 'Досмотры на контрольно-пропускных пунктах также стали гораздо более пристальными после событий 11 сентября 2001 года.'})
# №48 -- Процесс рассуждения:
# 1. Текст подчеркивает использование электронных устройств вместо точилок.
# 2. Это не относится к развлечениям, географии, здоровью, политике, науке и технологиях, спорту или путешествиям.
# 3. Тема, которая лучше всего подходит - это связанность использования электронных устройств вместо физических инструментов (точилок).
#
# ОТВЕТ: technology ({'index_id': 1642, 'category': 'science/technology', 'text': 'Сейчас люди пишут сообщения на экранах компьютеров, и им никогда не приходится иметь дело с точилкой.'})
# №49 -- Процесс рассуждения:
# 1. В тексте говорится о хвосте динозавра и его оперении.
# 2. Это не относится ни к развлечениям, ни к природе и географии, ни к здоровью, ни к политике, ни к спорту, ни к путешествиям.
# 3. Текст содержит научную информацию о предположениях исследователей о характере хвоста и оперения конкретного динозавра.
#
# ОТВЕТ: science/technology ({'index_id': 1029, 'category': 'science/technology', 'text': 'Исследователи предположили, что, несмотря на то, что это хвост молодого динозавра, данный образец имеет оперение взрослой особи, а не пух цыплёнка.'})
# №50 -- Процесс рассуждения: В данном тексте речь идет о понятии pH и его определении. pH - это показатель, который связан с химическими соединениями и их электролитным составом. Это область знаний, которая относится к науке о химии. Тема, которая наиболее соответствует этому содержанию, это "science/technology".
#
# Ответ:
# science/technology ({'index_id': 1343, 'category': 'science/technology', 'text': 'Показатель pH определяется степенью насыщенности ионами водорода (H в pH) исследуемого химического соединения.'})
# №51 -- Процесс рассуждения: В данном тексте затрагиваются проблемы записи DVD и отсутствие субтитров при записи. Эти вопросы связаны с технологиями и электроникой, но не относятся к области развлечений, географии, здоровью, политике, науке/технологии или спорту. Тема путешествий тоже не подходит, поскольку текст не имеет отношение к поездкам или туристическим вопросам.
#
# Выбранная тема: technology ({'index_id': 463, 'category': 'science/technology', 'text': 'К сожалению, когда вы записываете DVD, изображение по границам экрана также скорее всего будут отрезано, и, если субтитры на видео расположены близко к нижнему краю экрана, их не будет видно целиком.'})
# №52 -- При рассмотрении данного текста становится ясно, что он не содержит элементов, связанных ни с темами entertainment, geography, health, politics, science/technology или sports. Текст просто сообщает о том, что не сообщалось о задержках на дорогах.
#
# ВАШ ОТВЕТ: travel ({'index_id': 260, 'category': 'travel', 'text': 'О существенных задержках движения на кольцевой автодороге, дополнительной городской трассе, не сообщалось.'})
# №53 -- Процесс рассуждения:
# Текст говорит о кошках и их способности к捕猎不同大小的猎物，从兔子到鹿。这明显与自然环境和地理位置无关（地理学），也不涉及健康、政治、科学和技术或体育等领域。此外，这段文字并没有提及娱乐活动、旅行或政治议题。
# ВАШ ОТВЕТ: travel ({'index_id': 1356, 'category': 'science/technology', 'text': 'Под ними находятся большее количество кошек среднего размера, которые едят некрупную по величине добычу от кроликов до антилоп и оленей.'})
# №54 -- Процесс рассуждения:
# В данном тексте речь идет о заражении птичьего гриппа H5N1, смертельного для людей, мёртвой дикой утке на болоте. Этот факт относится к вопросам здравоохранения и общественного здоровья, поскольку он затрагивает людей, могут быть заражены, а также связан с научными исследованиями и контрольными мерами по защите общественности.
#
# Выбранная тема: health
#
# health ({'index_id': 1181, 'category': 'health', 'text': 'Было подтверждено, что штаммом птичьего гриппа H5N1, смертельного для людей, была заражена мёртвая дикая утка, найденная в понедельник на болоте рядом с Леоном в восточной Франции.'})
# №55 -- Процесс рассуждения:
# В данном тексте речь идет о историческом развитии технологии и строительства путей. Текст не затрагивает ни аспекты развлечений, ни вопросы здоровья, ни политические события, ни научные исследования, ни спортивные состязания, ни туристические маршруты. Он описывает технологический прогресс в области транспорта.
#
# Выбранная тема: science/technology ({'index_id': 1556, 'category': 'science/technology', 'text': 'Шпалы начали применяться довольно давно для того, чтобы удерживать рельсы на месте. Однако впоследствии стало ясно, что пути были более эффективны при полосе из железа сверху.'})
# №56 -- Процесс рассуждения:
# 1. Текст не содержит никаких элементов, связанных с развлечениями, наукой, технологиями, спортом, политикой или туризмом.
# 2. Текст не касается географии местности или её обозначений.
# 3. Он не обсуждает здоровье или медицинские вопросы.
# 4. Отсутствуют упоминания о поездках, путешествиях или туристических мероприятиях.
# 5. Текст не содержит политической или общественной информации.
#
# Выбранная тема: health ({'index_id': 1577, 'category': 'health', 'text': 'Лучшим признаком внутреннего отравления может быть наличие открытой ёмкости с лекарством или токсичным бытовым химическим веществом.'})
# №57 -- Процесс рассуждения: Текст указывает на возможность наблюдения за северным сиянием, что связано с качеством ночного неба. Однако это не имеет прямого отношения к темам, таким как спорт, наука/технологии, политика, здоровье, туризм или развлекательные мероприятия. Тема "география" также не совсем подходяща, так как текст не описывает конкретные географические местоположения или процессы в географии.
#
# Выбранная тема: travel ({'index_id': 2003, 'category': 'travel', 'text': 'Это представляет хорошую возможность увидеть северное сияние, потому что небо будет более или менее тёмным круглые сутки.'})
# №58 -- Процесс рассуждения:
# 1. В данном тексте говорится о размерах Турции и сравнении её территории с Францией и Великобританией.
# 2. Это касается географического пространства и картографии.
# 3. Тема "geography" наиболее точно соответствует содержанию данного текста.
#
# ДВА ""
# geography ({'index_id': 430, 'category': 'geography', 'text': 'Турция занимает 37-е место в мире по величине территории. Она примерно размера Метрополии Франции и Великобритании вместе взятыx.'})
# №59 -- Процесс рассуждения: В данном тексте речь идет о политических личностях - Ньют Гингриче, Рик Перри и Мишель Бахман. Эти люди занимают высокие посты в политической системе США. Они не связаны с развлечениями, географией, здоровьем, наукою и технологиями или спортом.
#
# Выбранная тема: politics ({'index_id': 1188, 'category': 'politics', 'text': 'Бывший спикер палаты Ньют Гингрич, губернатор Техаса Рик Перри и конгресмен Мишель Бахман заняли четвертое, пятое и шестое места соответственно.'})
# №60 -- Процесс рассуждения:
# В данном тексте говорится о расстоянии до архипелага от полуострова и о крупнейшем острове, названном в честь короля Георга. Это описание географического положения и некоторых местных особенностей, характерных для данной территории.
#
# Выбранное слово: geography ({'index_id': 1901, 'category': 'geography', 'text': 'Архипелаг располагается в 120 километрах от полуострова. Крупнейшим остров носит имя Короля Георга с поселением Вилья-лас-Эстрельяс.'})
# №61 -- Процесс рассуждения: В данном тексте речь идет о президенте США Джордже Буше и его приветствии. Это не относится к развлекательным мероприятиям, географическим фактам, здоровью, политике, науке и технике, спорту или путешествиям. Текст не содержит никаких упоминаний этих тем.
#
# Выбранная тема: politics ({'index_id': 1075, 'category': 'politics', 'text': 'Президент США Джордж Буш приветствовал это заявление.'})
# №62 -- Процесс рассуждения:
# 1. В задании говорится о "Дисней Уорлде", что является популярным развлекательным комплексом.
# 2. Дисней Лэнд известен своим развлекательным контентом, фильмами, мультфильмами, анимацией и прочими развлечениями.
# 3. Тема путешествий и посещения мест не относится к основной функции Дисней Лэнда.
# 4. Географическая тема здесь не проявляется, так как речь идет о конкретном месте, а не о широком пространстве.
# 5. Здоровье также не является ключевой темой, так как это не относится к основной деятельности Дисней Лэнда.
# 6. Политика не имеет отношения к Дисней Лэнду.
# 7. Наука и технологии тоже не являются главными ({'index_id': 666, 'category': 'travel', 'text': 'Есть бесчисленное множество возможных вариантов, но большинство людей, говоря о посещении "Дисней Уорлда", все же подразумевают именно это.'})
# №63 -- Процесс рассуждения:
# В данном тексте речь идет о стратегии завоевания африканских государств Италией. Он описывает необходимость создания плацдарма в виде какой-то страны для перехода через Средиземное море. Этот текст не имеет прямого отношения к любой из указанных тем, кроме "travel". Тем не менее, "travel" не совсем соответствует контексту, так как здесь речь идет не о путешествии, а о стратегии завоевания.
#
# Выбранная тема: politics ({'index_id': 398, 'category': 'politics', 'text': 'Главной целью Италии были африканские государства. Для захвата этих стран нужен был плацдарм для войск, чтобы отряды могли переплыть Средиземное море и атаковать Африку.'})
# №64 -- Процесс рассуждения: В данном тексте говорится о том, что фавориты турнира из Южной Африки одержали победу над другой командой. Это указывает на спортивную или футбольную сферу, поскольку речь идет о比赛中。 ОТВЕТ: sports ({'index_id': 1150, 'category': 'sports', 'text': 'Фавориты турнира из Южной Африки начали с правильной ноты, когда одержали красивую победу со счетом 26-00 над Замбией, находящейся на 5-ой позиции.'})
# №65 -- Процесс рассуждения:
# В данном тексте нет никаких элементов, относящихся к развлекательным мероприятиям, географическим явлениям, здоровью, политике, науке и технологиям, спорту или путешествию. Вместо этого текст описывает событие, связанное с общественной ситуацией, где группа людей выходит в город в карете и вызывает народный гнев и опасение.
#
# Выбранная тема:
# travel ({'index_id': 1469, 'category': 'politics', 'text': 'Они вернулись в Париж в карете, окружённые толпой людей, которые выкрикивали угрозы королю и королеве.'})
# №66 -- Процесс рассуждения:
# 1. В данном тексте речь идет о высказывании спортсмена.
# 2. Тема спорта (sports) наиболее точно соответствует контексту высказывания о драках женщин.
# 3. Олимпийские игры - это крупное спортивное событие.
# 4. Отношение к дракам женщин - это вопрос восприятия и стереотипов, но не касается здоровья, политики, науки или культуры конкретного региона.
#
# Выбранная тема: sports ({'index_id': 219, 'category': 'sports', 'text': 'Серебряный медалист Олимпийских игр 2004 года Амир Хан сказал: "В глубине души я считаю, что женщины не должны драться. Это мое личное мнение".'})
# №67 -- Процесс рассуждения:
# 1. Анализируем текст: "Пекин станет местом проведения церемоний открытия и закрытия, а также ледовых мероприятий в помещениях."
# 2. Определяем ключевые слова и идею: Пекин, церемонии, мероприятия, ледовые.
# 3. Сравниваем с перечнем тем: entertainment, geography, health, politics, science/technology, sports, travel.
# 4. Видим, что церемонии и мероприятия не соответствуют темам entertainment, health, politics, science/technology, sports.
# 5. Тема geography не подходит, так как текст не обсуждает географические особенности Пекина.
#
# Выбранная тема: sports ({'index_id': 767, 'category': 'sports', 'text': 'Пекин станет местом проведения церемоний открытия и закрытия, а также ледовых мероприятий в помещениях.'})
# №68 -- Приступим к анализу текста: "Эта теория противоречит утверждению, что Луна полностью лишена геологической активности."
#
# В данном контексте речь идет о научных исследованиях и утверждениях относительно Луны. Это касается научной области, связанной с космическими исследованиями и геологией.
#
# ОТВЕТ: science/technology ({'index_id': 229, 'category': 'geography', 'text': 'Эта теория противоречит утверждению, что Луна полностью лишена геологической активности.'})
# №69 -- Процесс рассуждения: В данном тексте речь идет о строении глаз и его сложности. Это не относится к развлечениям, географии, здоровью, политике, науке и технологиях или спорту. Тема, которая лучше всего соответствует содержанию текста, это "science/technology".
#
# ВЫБРАННАЯ ТЕМА: science/technology ({'index_id': 567, 'category': 'health', 'text': 'Существует множество различных строений глаз, сложность которых варьируется в зависимости от потребностей организма.'})
# №70 -- Процесс рассуждения:
# 1. В данном тексте упоминается Шенгенская зона, которая является международной зоной свободного передвижения граждан.
# 2. Обсуждается, что эта зона работает как единая страна.
# 3. Тема Шенгенской зоны не относится к разным категориям, кроме travel (туризм).
#
# ОТВЕТ: travel ({'index_id': 1855, 'category': 'travel', 'text': 'Но Шенгенская зона в этом плане функционирует как единая страна.'})
# №71 -- Процесс рассуждения:
# В данном тексте речь идет о политической карьере Бжезинского, его работе в двух президентских администрациях - Кеннеди и Джонсоне. Тема не связана с развлечениями, географией, здоровьем, науке/технологиями, спортом или путешествиями. Она касается политического процесса и работы в государственных структурах.
#
# ДВА ""
# politics ({'index_id': 1014, 'category': 'politics', 'text': 'В 1960-х гг. Бжезинский занимал должность советника при Джоне Ф. Кеннеди, затем в администрации Линдона Б. Джонсона.'})
# №72 -- Процесс рассуждения:
# В данном тексте речь идет о политическом событии - о том, что Люксембург стал одним из первооснователей Европейского Союза в 1957 году. Это явно относится к политике.
#
# Выбранная тема: politics ({'index_id': 435, 'category': 'politics', 'text': 'В 1957 году Люксембург стал одним из государств-основателей организации, которая известна сейчас как Европейский Союз.'})
# №73 -- Процесс рассуждения:
# В тексте упоминается французская оперетта Камиль Сен-Санса, которая повествует о художнике, чья жизнь "управляет любовью к наркотикам и к Японии". Здесь мы имеем отношение к искусству и музыкальному творчеству. Однако среди предлагаемых тем "science/technology", "health", "politics", "geography", "travel" и "entertainment" наиболее подходящей будет тема "entertainment", так как оперетта - это вид театрального искусства, который относится к сфере развлечений.
#
# ОТВЕТ: entertainment ({'index_id': 1186, 'category': 'entertainment', 'text': 'История, рассказанная во французской опере Камилем Сен-Сансом, повествует о художнике, "жизнью которого управляет любовь к наркотикам и к Японии".'})
# №74 -- Процесс рассуждения:
# 1. В данном тексте не упоминается ни о каких развлечениях или артефактах, связанных с развлечением.
# 2. Нет упоминания о географических особенностях или изменении местоположения.
# 3. Тема здоровья не связана с содержанием текста.
# 4. Политика и правительственные решения не являются предметом данного текста.
# 5. Наука и технологии также не являются темой этого текста.
# 6. Спорт не имеет отношения к событиям, описанным в тексте.
# 7. Последняя тема - путешествия и туризм - наиболее подходящая тема, так как речь идет о поездках и перемещениях, связанных с войной и политикой.
#
# Выбранная тема: travel ({'index_id': 384, 'category': 'politics', 'text': 'После первоначальных военных неудач Этельред смог договориться об условиях с Олафом, который вернулся в Норвегию, чтобы с переменным успехом пытаться завоевать свое королевство.'})
# №75 -- Процесс рассуждения: В данном тексте нет никаких упоминаний критериев, характерных для темы entertainment, geography, health, politics, science/technology или sports. Также нет упоминания о путешествиях или культурном потрясении, что исключает тему travel. В тексте говорится только о том, что человек был перемещён в госпиталь.
#
# Выбранная тема: health ({'index_id': 1282, 'category': 'health', 'text': 'В последствие он был перемещён в госпиталь Адденбрук в Кембридже.'})
# №76 -- Приступим к анализу текста: "Пик туристического сезона в горных деревушках обычно приходится на индийское лето."
# Процесс рассуждения:
# 1. Текст не содержит никаких упоминаний о развлечениях, культурах, медицине, политической ситуации, науке, спорте или путешествиях.
# 2. Текст говорит о сезоне, который характерен для туристов в определенных местах (горные деревушки) и его периоде (индийское лето).
# 3. Таким образом, текст не соответствует ни одной из предложенных тем.
#
# ОТВЕТ: geography ({'index_id': 992, 'category': 'travel', 'text': 'Пик туристического сезона в горных деревушках обычно приходится на индийское лето.'})
# №77 -- Процесс рассуждения:
# В данном тексте речь идет о природных объектах - острове Ливингстон и затопленной кальдере вулкана. Эти объекты находятся в природных условиях, что делает их более соответствующими теме "geography".
#
# Выбранная тема: geography ({'index_id': 1902, 'category': 'geography', 'text': 'Прочие включают остров Ливингстон и Десепшен, где затопленная кальдера активного до настоящего времени вулкана представляет из себя впечатляющую природную гавань.'})
# №78 -- Процесс рассуждения:
# 1. Текст представляет собой результат соревнования в гигантском слаломе.
# 2. Упоминаются конкретные имена спортсменок и результаты их соревнований.
# 3. Речь идет о времени, которое спортсменки затрачивали на финиш.
# 4. Спортсменки из разных стран участвуют в соревновании.
# 5. Текст не содержит элементов, характерных для других тем из списка.
#
# Выбранная тема: sports ({'index_id': 1272, 'category': 'sports', 'text': 'В другой гонке, на этот раз уже в гигантском слаломе, она финишировала десятой среди женщин в позиции сидя с комбинированным временем 4:41,30. На 2:11,60 минуты медленнее, чем финишировавшая первой австрийка Клаудия Леш и на 1:09,02 минуту медленнее, чем финишировавшая девятой венгерка Дьенджи Дани.'})
# №79 -- Процесс рассуждения: В данном тексте речь идет о спорте и конкретном сете теннисного матча. В тексте упоминается "тай-брейк", "сеты", "первый сет", "тай-брейк после первого сета". Эти элементы указывают на спорт, в частности на теннис.
#
# Выбранная тема: sports ({'index_id': 1224, 'category': 'sports', 'text': 'Муррэй  проиграл первый сет в тай-брейке после того, как оба мужчины отбивали абсолютно все подачи в сете.'})
# №80 -- Процесс рассуждения:
# 1. Текст описывает шоу на фоне пирамиды, предназначенное для детей.
# 2. Шоу относится к развлекательной категории, поскольку его называют "интересным мероприятием".
# 3. Тема не связана с географией, медициной, политикой, науке, спортом или путешествием.
# 4. В тексте нет упоминания места, связанного с культурным потрясением или рекомендаций по безопасности.
#
# Выбранная тема: entertainment ({'index_id': 1895, 'category': 'entertainment', 'text': 'Звуковое и световое шоу на фоне пирамиды является одним из самых интересных мероприятий в этой местности для детей.'})
# №81 -- Процесс рассуждения:
# В данном тексте речь идет о иммиграционной проверке и таможенном контроле. Иммиграционная проверка обычно не является формальностью и может быть сложной. Таможенный контроль тоже часто требует времени и усилий. Оба эти термина относятся к вопросам путешествия и перемещения людей. Тема "travel" наиболее точно соответствует контексту данного текста.
#
# ВАШ ОТВЕТ: travel ({'index_id': 938, 'category': 'travel', 'text': 'Хотя иммиграционная проверка, как правило, отсутствует или представляет собой формальность по возвращении на родину, таможенный контроль может быть хлопотным.'})
# №82 -- Процесс рассуждения:
# В данном тексте говорится о том, что человек имеет возможность наслаждаться отпуском дома и уделять время для приготовления чего-то особенного. Это больше относится к сфере личного удовольствия и отдыха.
#
# Выбранная тема: entertainment
#
# , entertainment ({'index_id': 872, 'category': 'travel', 'text': 'Когда вы проводите отпуск дома, у вас есть время, чтобы побаловать себя и уделить несколько дополнительных минут, чтобы приготовить нечто особенное.'})
# №83 -- Процесс рассуждения:
# 1. Текст рассматривает атомы и их ядра.
# 2. Обсуждается свойство атомов иметь нестабильное ядро и его последствия.
# 3. Этот вопрос относится к области физики и атомной структуры, что соответствует теме "science/technology".
# 4. Из предоставленного списка тем, только одна из них полностью соответствует данному контексту.
#
# ОТВЕТ: science/technology ({'index_id': 1646, 'category': 'science/technology', 'text': 'Некоторые атомы имеют нестабильное ядро, что означает, что они склонны распадаться при малом воздействие или без него.'})
# №84 -- Процесс рассуждения:
# В данном тексте речь идет о заявлении президента США о выводе американских войск из Сирии. Это политический шаг, который связан с международными отношениями и внешней политикой страны.
#
# Выбранная тема: politics
#
#  politics ({'index_id': 1021, 'category': 'politics', 'text': 'Поздно вечером в воскресенье президент США Дональд Трамп через пресс-секретаря заявил, что войска США покинут Сирию.'})
# №85 -- Процесс рассуждения:
# В данном тексте речь идет о технологической возможности спутника, который способен принимать звонок и немедленно отражать его обратно на Землю. Это указывает на использование научных достижений и технологий в космонавтике.
#
# Выбранная тема:
# science/technology ({'index_id': 1351, 'category': 'science/technology', 'text': 'Спутник в космосе принимает звонок и практически мгновенно отражает его обратно вниз.'})
# №86 -- Процесс рассуждения:
# 1. Текст говорит о математике и математическом открытии Пифагора.
# 2. Тема не относится ни к развлечениям, ни к географии, ни к здоровью, ни к политике, ни к науке и технологиям, ни к спорту.
# 3. Тема также не касается путешествий или туризма.
#
# Выбранная тема: science/technology ({'index_id': 415, 'category': 'science/technology', 'text': 'Другим известным греком является математик Пифагор, известный, главным образом, благодаря своей знаменитой теореме о соотношениях сторон прямоугольных треугольников.'})
# №87 -- Процесс рассуждения: В данном тексте затрагиваются научные идеи и взгляды относительно структуры Солнечной системы, а также мнения людей. Однако основное внимание уделяется научной теории о месте Земли в Солнечной системе. Тема, которая наиболее соответствует содержанию данного текста, - это "science/technology".
#
# ВАШ ОТВЕТ: science/technology ({'index_id': 1620, 'category': 'science/technology', 'text': 'Многие считали, что он прав, но многие верили в противоположное: что Солнечная система вращается вокруг Земли, включая Солнце (и даже другие звезды).'})
# №88 -- Процесс рассуждения: В тексте упоминаются казино, которые стараются, чтобы посетители проводили много времени и тратили больше денег в заведении. Эти действия характерны для развлекательных заведений. Тема "travel" здесь не подходит, так как речь идет не о путешествиях, а о специфическом типе заведения. Тема "health" не применима. Тема "politics" не относится к содержанию текста. Тема "science/technology" не имеет отношения к казино. Тема "sports" не подходит. Тема "geography" не применима.
#
# Выбранная тема: entertainment ({'index_id': 1796, 'category': 'entertainment', 'text': 'Обычно казино прилагают все усилия, чтобы посетители проводили как можно больше времени и тратили как можно больше денег в заведении. Окон и часов там нет, а выходы бывает трудно найти.'})
# №89 -- Процесс рассуждения:
# В данном тексте говорится о способах путешествовать и проводить время без использования яхты, рассматривая альтернативные варианты, такие как исследование архипелагов или посещение озер. Этот контекст связан с туризмом и путешествиями.
#
# Выбранная тема: travel ({'index_id': 1915, 'category': 'entertainment', 'text': 'Исследуя архипелаги или посещая озера, вы вполне сможете обойтись и без яхты.'})
# №90 -- Процесс рассуждения:
# В данном тексте говорится о необходимости осторожности при посещении тропического леса, особенно в период лета. Здесь подчеркивается опасность комаров. Это связано с риском заражения тифом или другими болезнями, передающимися через комаров.
#
# Выбранное слово:
# travel
#
# Ответ: travel ({'index_id': 981, 'category': 'health', 'text': 'Если вы решите путешествовать по тропическому лесу – остерегайтесь комаров, особенно летом.'})
# №91 -- Процесс рассуждения: В данном тексте речь идет о фильме, который получил номинации во всех главных категориях. Это указывает на то, что речь идет о кино или театральной деятельности, что может относиться к области культуры и развлечений. Тем не менее, среди представленных тем "entertainment" наиболее точно соответствует данному контексту.
#
# Ответ:
# entertainment ({'index_id': 1017, 'category': 'entertainment', 'text': 'Этот фильм с участием Райана Гослинга и Эммы Стоун получил номинации во всех главных категориях.'})
# №92 -- Процесс рассуждения:
# В данном тексте говорится о том, что стоит уделить время прогулке по необычной деревне. Это указывает на интерес к местной природе и культуре, что характерно для путешествия или посещения чего-то необычного.
#
# Выбранная тема: travel ({'index_id': 1944, 'category': 'entertainment', 'text': 'Стоит уделить полчаса и прогуляться по необычной деревне.'})
# №93 -- Процесс рассуждения:
# 1. Объект текста - звёзды и процесс их свето-теплового выхода.
# 2. В тексте упоминается атомное соединение и образование из него более тяжёлых элементов.
# 3. Этот процесс связан с физическими законами и наукой, что указывает на область знаний и исследований.
# 4. Из предоставленного списка тем наиболее подходящей является "science/technology".
# ОТВЕТ: science/technology ({'index_id': 348, 'category': 'science/technology', 'text': 'Звёзды испускают свет и тепло, поскольку при слияние (или соединения) атомов водорода и образования из них более тяжёлых элементов создаётся энергия.'})
# №94 -- Процесс рассуждения: В данном тексте упоминается имя игрока, которое было признано лучшим за всю историю одной футбольной команды ("Партизан"). Это указывает на спортивную деятельность и достижение в спорте. Тема, связанная с спортом, наиболее точно соответствует контексту.
#
# Выбранная тема: sports
#
# ", sports ({'index_id': 331, 'category': 'sports', 'text': 'В 1995 году его признали лучшим игроком за всю историю "Партизана".'})
# №95 -- Приступим к анализу текста: "Прерывание сна — это процесс целенаправленного пробуждения во время обычного сна и повторного засыпания через короткое время (10–60 минут)."
#
# Этот текст не связан ни с развлечениями, географией, здоровьем, политикой, наукою и технологиями, спортом или путешествием.
#
# Тема, наиболее подходящая для данного текста - это "health" (здоровье), так как это вопрос о процессах, происходящих в организме человека во время сна.
#
# ОТВЕТ: health ({'index_id': 1530, 'category': 'health', 'text': 'Прерывание сна — это процесс целенаправленного пробуждения во время обычного сна и повторного засыпания через короткое время (10–60 минут).'})
# №96 -- Процесс рассуждения: В данном тексте речь идет о применении компьютеров для обработки фотографий и видеоматериалов. Эти функции являются частью технологического прогресса и применения инноваций в сфере IT-технологий. Темы "science/technology" и "sports" здесь не применимы.
#
# Выбранная тема: science/technology
#
# ", science/technology ({'index_id': 610, 'category': 'science/technology', 'text': 'Сегодня компьютеры используются, чтобы обрабатывать фотографии и видеоматериалы.'})
# №97 -- Процесс рассуждения:
# 1. Текст рассматривает местные названия и описание местности в Ругаланне и Агдере.
# 2. Определение "hei" как безлесой пустоши, покрытой вереском, относится к описанию природных условий.
# 3. Этот текст не имеет ничего общего с развлечениями, здоровьем, политическими событиями, наукоемкими технологиями, спортом или путешествиями.
# 4. Тема "geography" включает описание местности, климата и природы.
#
# В итоге текст наиболее соответствует теме "geography".
#
# ВЫБРАННАЯ ТЕМА: geography ({'index_id': 988, 'category': 'geography', 'text': 'В Ругаланне и Агдере их обычно называют "hei", что означает безлесую пустошь, часто покрытую вереском.'})
# №98 -- Процесс рассуждения:
# В данном тексте речь идет о политической позиции граждан Австралии по вопросу о переходе страны к республиканскому строю. Это касается политического устройства страны и мнений ее граждан, что указывает на политическую тематику.
#
# Выбранная тема: politics ({'index_id': 1322, 'category': 'politics', 'text': 'Опрос показал следующее: 29 процентов респондентов уверены, что Австралия должна как можно скорее стать республикой, а 31 процент полагает, что ей не нужна эта форма государственного устройства.'})

# %%
validation_clarification_set = datasets.Dataset.from_list(validation_clarification_set)

print(validation_clarification_set)
# Out:
# Dataset({
#     features: ['index_id', 'category', 'text'],
#     num_rows: 99
# })

# %% [markdown]
# ### Уточняем некорректные ответы

# %%
prompt_system_2 = 'Вы — умный ассистент, умеющий читать и анализировать тексты ' \
                  'на русском языке, всегда дающий продуманные верные ответы. '

prompt_user_2 = 'Робот выполнял разделение текстов на темы, однако ' \
                'не смог определить темы некоторых текстов однозначно. ' \
                'Ваша задача — выбрать одну тему из списка тем ниже. ' \
                'Если ваш ответ будет содержать тему, которой в списке ' \
                'ниже НЕТ, он будет считаться НЕКОРРЕКТНЫМ И ОТКЛОНЁН!'

# %%
validation_clarification_set_for_llm = validation_clarification_set.map(
    lambda it: prepare_message_for_llm(
        it['text'],
        examples_by_categories,
        prompt_system_2,
        prompt_user_2
    )
)
# Out:
# Map:   0%|          | 0/99 [00:00<?, ? examples/s]

# %%
print(validation_clarification_set_for_llm)
# Out:
# Dataset({
#     features: ['index_id', 'category', 'text', 'message_for_llm'],
#     num_rows: 99
# })

# %%
validation_clarification_pred = list(map(
    lambda x: LLM_PIPELINE(x, max_new_tokens=10)[0]['generated_text'],
    tqdm(validation_clarification_set_for_llm['message_for_llm'])
))
validation_clarification_true = validation_clarification_set['category']
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
print(validation_clarification_pred[0])
# Out:
# [{'content': 'Вы — умный ассистент, умеющий читать и анализировать тексты на русском языке, всегда дающий продуманные верные ответы. ', 'role': 'system'}, {'content': 'Робот выполнял разделение текстов на темы, однако не смог определить темы некоторых текстов однозначно. Ваша задача — выбрать одну тему из списка тем ниже. Если ваш ответ будет содержать тему, которой в списке ниже НЕТ, он будет считаться НЕКОРРЕКТНЫМ И ОТКЛОНЁН!\nПРИМЕР: Это когда люди посещают место, которое очень отличается от их обычной повседневной жизни, чтобы расслабиться и развлечься. \nОТВЕТ: entertainment \nПРИМЕР: Вечер начал певец Санджу Шарма, за ним выступил Джай Шанкар Чаудхари. esented the chhappan bhog bhajan также. Ему аккомпанировал певец Раджу Кханделвал. \nОТВЕТ: entertainment \nПРИМЕР: Пятнадцать из этих метеоритов связывают с метеоритным дождем, прошедшим в июле прошлого года. \nОТВЕТ: geography \nПРИМЕР: Некогда древний город Смирна сегодня — современный, развитый и оживленный торговый центр, расположившийся вдоль огромного залива и окруженный горами. \nОТВЕТ: geography \nПРИМЕР: Тем, кто тренируется постоянно, требуется больше поддержки по причине негативного отношения к боли и для того, чтобы отличить хронические боли от чувства дискомфорта после обычных физических нагрузок. \nОТВЕТ: health \nПРИМЕР: Они научились мастерски делать ампутации, чтобы спасать пациентов от гангрены, и так же хорошо освоили жгут и артериальные зажимы для приостановки кровотока. \nОТВЕТ: health \nПРИМЕР: Администратор Commons Адам Керден выразил своё разочарование в связи с удалениями в своем разговоре  в прошлом месяце с Wikinews. \nОТВЕТ: politics \nПРИМЕР: Вчера Мартейи привёл к присяге новый Временный избирательный совет (ВИС), состоящий из девяти участников. \nОТВЕТ: politics \nПРИМЕР: На следующем изображении показаны атомы, излучающие фотоны. Конечно, в действительности фотоны намного меньше, чем те, которые изображены на картинке. \nОТВЕТ: science/technology \nПРИМЕР: Использование Интернета и Всемирной паутины позволяет учащимся иметь доступ к информации в любой момент. \nОТВЕТ: science/technology \nПРИМЕР: Первая голевая передача Овечкина в тот вечер принесла команде победный гол, выполненный новичком Никласом Бекстрёмом; \nОТВЕТ: sports \nПРИМЕР: Итальянская сборная по футболу, наряду с немецкой, является второй самой успешной командой в мире и в 2006 году выиграла Кубок мира ФИФА. \nОТВЕТ: sports \nПРИМЕР: Если на страну, которую вы собираетесь посетить, распространяются  рекомендации с предупреждением об опасности их посещения, то это может повлиять на вашу медицинскую страховку во время поездки или на вашу страховку от отмены поездки. \nОТВЕТ: travel \nПРИМЕР: Путешествуя впервые по одной из развивающихся стран или попадая в ту часть света, где вы раньше не бывали, будьте готовы в возможному сильному  культурному потрясению. \nОТВЕТ: travel \nЗАДАНИЕ: Если увеличить расстояние для бега с четверти до половины мили, скорость становится не так важна, тогда как выносливость превращается в абсолютную необходимость. \nСПИСОК ТЕМ (выберите ОДНУ тему СТРОГО из этого списка): "entertainment; geography; health; politics; science/technology; sports; travel" \nВАШ ОТВЕТ: ', 'role': 'user'}, {'role': 'assistant', 'content': 'fitness \n\nОтвет "fitness" наиболее подходящ'}]

# %% [markdown]
# ### Объединяем результаты

# %%
combine_cnt = 0
for i in validation_clarification_idx:
    validation_pred[i] = validation_clarification_pred[combine_cnt]
    combine_cnt += 1

# %%
print(m.classification_report(
    y_true=validation_true,
    y_pred=[x[-1]['content'] for x in validation_pred])
)
# Out:
#                                              precision    recall  f1-score   support
#
#                               entertainment       0.57      0.44      0.50         9
# fitness
#
# Ответ "fitness" наиболее подходящ       0.00      0.00      0.00         0
#                                   geography       0.62      0.62      0.62         8
#                                      health       0.80      0.36      0.50        11
#                              nature/animals       0.00      0.00      0.00         0
#                                    politics       1.00      0.64      0.78        14
#                          science/technology       0.73      0.88      0.80        25
#                                    security       0.00      0.00      0.00         0
#                                      sports       0.86      0.50      0.63        12
#                                      travel       0.53      0.80      0.64        20
#
#                                    accuracy                           0.67        99
#                                   macro avg       0.51      0.43      0.45        99
#                                weighted avg       0.73      0.67      0.67        99

# %% [markdown]
# ### Постобработка текста
#
# Делаем нечёткое сравнение строк по формуле Левенштейна, выбираем тему из списка с наименьшим расстоянием

# %%
validation_pred_norm = list(map(
    lambda it: process.extractOne(it[-1]['content'], list_of_categories, scorer=fuzz.token_sort_ratio)[0],
    validation_pred
))

# %%
print(m.classification_report(
    y_true=validation_true,
    y_pred=validation_pred_norm)
)
# Out:
#                     precision    recall  f1-score   support
#
#      entertainment       0.50      0.44      0.47         9
#          geography       0.62      0.62      0.62         8
#             health       0.80      0.36      0.50        11
#           politics       1.00      0.64      0.78        14
# science/technology       0.71      0.88      0.79        25
#             sports       0.75      0.50      0.60        12
#             travel       0.53      0.80      0.64        20
#
#           accuracy                           0.67        99
#          macro avg       0.70      0.61      0.63        99
#       weighted avg       0.70      0.67      0.66        99

# %% [markdown]
# # Тестовые данные

# %%
test_set_for_llm = test_set.map(
    lambda it: prepare_message_for_llm(
        it['text'],
        examples_by_categories,
        prompt_system_1,
        prompt_user_1
    )
)
# Out:
# Map:   0%|          | 0/204 [00:00<?, ? examples/s]

# %%
test_pred = list(map(
    lambda x: LLM_PIPELINE(x, max_new_tokens=10)[0]['generated_text'],
    tqdm(test_set_for_llm['message_for_llm'])
))
test_true = test_set['category']
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]

# %%
print(m.classification_report(
    y_true=test_true,
    y_pred=[x[-1]['content'].strip('.,:\'"* \n').split(' ')[-1].strip('.,:\'"* \n') for x in test_pred])
)
# Out:
#                     precision    recall  f1-score   support
#
#      entertainment       0.00      0.00      0.00      19.0
#          geography       0.00      0.00      0.00      17.0
#             health       0.00      0.00      0.00      22.0
#           politics       0.00      0.00      0.00      30.0
# science/technology       0.00      0.00      0.00      51.0
#             sports       0.00      0.00      0.00      25.0
#             travel       0.00      0.00      0.00      40.0
#                  В       0.00      0.00      0.00       0.0
#                  Т       0.00      0.00      0.00       0.0
#                виж       0.00      0.00      0.00       0.0
#               вижу       0.00      0.00      0.00       0.0
#           внимание       0.00      0.00      0.00       0.0
#             данном       0.00      0.00      0.00       0.0
#                зад       0.00      0.00      0.00       0.0
#                 оч       0.00      0.00      0.00       0.0
#             понима       0.00      0.00      0.00       0.0
#   рассуждение:
# Тем       0.00      0.00      0.00       0.0
#     рассуждения:
# 1       0.00      0.00      0.00       0.0
#    рассуждения:
# 1)       0.00      0.00      0.00       0.0
#   рассуждения:
# Тек       0.00      0.00      0.00       0.0
#              текст       0.00      0.00      0.00       0.0
#             текста       0.00      0.00      0.00       0.0
#            текста:       0.00      0.00      0.00       0.0
#               ясно       0.00      0.00      0.00       0.0
#             я注意到，S       0.00      0.00      0.00       0.0
#
#           accuracy                           0.00     204.0
#          macro avg       0.00      0.00      0.00     204.0
#       weighted avg       0.00      0.00      0.00     204.0

# %%
test_clarification_idx = []
test_clarification_set = []

for i, conversation in enumerate(test_pred):
    for entry in conversation:
        if entry['role'] == 'assistant' and entry['content'] not in list_of_categories:
            test_clarification_idx.append(i)

# %%
print(f'Ответы с выдуманными категориями ({len(test_clarification_idx)}):')

for i in test_clarification_idx:
    test_clarification_entry = test_set[i]
    test_clarification_entry['text'] #+= f' (неверая тема: {test_pred[i][-1]["content"]})'
    test_clarification_set.append(test_clarification_entry)
    
    print(f'№{int(i)} -- {test_pred[i][-1]["content"]} ({test_set[i]})')

test_clarification_set = datasets.Dataset.from_list(test_clarification_set)
# Out:
# Ответы с выдуманными категориями (204):
# №0 -- Процесс рассуждения:
# Т ({'index_id': 1523, 'category': 'science/technology', 'text': 'Мутация вносит новую генетическую вариацию, в то время как отбор убирает её из набора проявляющихся вариаций.'})
# №1 -- Процесс рассуждения: В данном ({'index_id': 1644, 'category': 'science/technology', 'text': 'Атомная бомба работает на том принципе, что для того, чтобы много протонов и нейтронов находились в одном ядре, необходима энергия.'})
# №2 -- Процесс рассуждения:
# Т ({'index_id': 558, 'category': 'science/technology', 'text': 'Ядро состоит из двух частиц — нейтронов и протонов.'})
# №3 -- Процесс рассуждения:
# 1. ({'index_id': 456, 'category': 'science/technology', 'text': 'Это позволило объективам с переменным фокусным расстоянием создавать снимки качества, сравнимого с качеством, получаемым объективами с постоянным фокусным расстоянием.'})
# №4 -- Процесс рассуждения: В данном ({'index_id': 906, 'category': 'science/technology', 'text': 'Они лучше веб-прокси по ряду причин: они пересылают весь веб-трафик, а не только трафик по HTTP-протоколу.'})
# №5 -- Процесс рассуждения:
# В данном ({'index_id': 452, 'category': 'science/technology', 'text': 'Для работы над интерактивным дизайном вам потребуется переоценить ваши представления об информационной индустрии и научиться нестандартно мыслить.'})
# №6 -- Процесс рассуждения:
# В ({'index_id': 1557, 'category': 'science/technology', 'text': 'Это стало общепринятой практикой, но железо приводило к большему износу деревянных колёс вагонов.'})
# №7 -- При чтении текста я понима ({'index_id': 1360, 'category': 'science/technology', 'text': 'В состав прайда входит от одного до трех взрослых самцов, находящихся в родстве, а также самок и детенышей, число которых может доходить до тридцати.'})
# №8 -- Процесс рассуждения:
# 1. ({'index_id': 1675, 'category': 'science/technology', 'text': 'Несмотря на то, что ИИ прочно ассоциируется с научной фантастикой, он формирует очень важное направление компьютерных наук, рассматривающее поведение и обучение машин и "привитие" им интеллекта.'})
# №9 -- Процесс рассуждения:
# 1. ({'index_id': 1430, 'category': 'science/technology', 'text': 'Соотношение сторон этого формата (поделенное на двенадцать, чтобы получить соотношение с небольшими целыми числами) поэтому принято за 3:2.'})
# №10 -- Процесс рассуждения:
# 1) ({'index_id': 1907, 'category': 'science/technology', 'text': 'Как правило, спутниковый телефон не является заменой мобильному телефону, поскольку вам необходимо находиться на улице в зоне прямой видимости со спутника, чтобы позвонить.'})
# №11 -- Процесс рассуждения:
# 1. ({'index_id': 1555, 'category': 'science/technology', 'text': 'Хотя гужевые дороги представляли собой лишь размещенные параллельно бруски дерева, они давали лошадям возможность перевозить по ним более крупные грузы и с более высокой скоростью, чем по слегка более ухабистым дорогам того времени.'})
# №12 -- Процесс рассуждения:
# В текст ({'index_id': 1632, 'category': 'science/technology', 'text': 'Людям с античных времен были известны основные химические элементы, такие как золото, серебро и медь, поскольку их все можно встретить в природе в чистом виде и относительно легко добывать с помощью примитивных орудий.'})
# №13 -- При чтении текста я понима ({'index_id': 1354, 'category': 'science/technology', 'text': 'Колесо невероятным образом изменило наш мир. Самое главное, что колесо сделало для нас, — подарило нам гораздо более лёгкую и быструю транспортировку.'})
# №14 -- Процесс рассуждения: В данном ({'index_id': 462, 'category': 'science/technology', 'text': 'Это сделано для того, чтобы изображение охватывало весь экран. Это называется растянутая развёртка.'})
# №15 -- Процесс рассуждения: В данном ({'index_id': 404, 'category': 'science/technology', 'text': 'Немецкие подводные лодки назывались U-Boat. Немцы очень хорошо разбирались в навигации и управлении своими подлодками.'})
# №16 -- Процесс рассуждения: В данном ({'index_id': 604, 'category': 'science/technology', 'text': 'Ее физическое состояние может меняться, но химическое состояние остается прежним.'})
# №17 -- Процесс рассуждения:
# 1. ({'index_id': 352, 'category': 'science/technology', 'text': 'Поверхностное натяжение происходит из-за того, что молекулы воды на поверхности воды притягиваются друг к другу сильнее, чем к молекулам воздуха над ними.'})
# №18 -- Процесс рассуждения:
# Т ({'index_id': 459, 'category': 'science/technology', 'text': 'Одной из наиболее распространённых проблем при попытке конвертирования фильма в формат DVD является вылет развертки.'})
# №19 -- Процесс рассуждения: В данном ({'index_id': 1519, 'category': 'science/technology', 'text': 'В частности, утверждается, что можно определить, лжет ли человек, при помощи правильной интерпретации его микровыражений.'})
# №20 -- Процесс рассуждения:
# Т ({'index_id': 1338, 'category': 'science/technology', 'text': 'Золоту можно придать любую форму. Его можно cкатать в очень малые формы.'})
# №21 -- Процесс рассуждения:
# 1. ({'index_id': 1679, 'category': 'science/technology', 'text': 'В настоящее время система ИИ часто используется в областях экономики, медицины, инженерии и военной сферы, будучи встроенной в некоторые программные приложения для домашних компьютеров и видеоигр.'})
# №22 -- Процесс рассуждения:
# 1. ({'index_id': 1428, 'category': 'science/technology', 'text': 'Сегодня её всё ещё производят, но более важно то, что её соотношение сторон унаследовали размеры изображений цифровых камер.'})
# №23 -- Процесс рассуждения: В данном ({'index_id': 1432, 'category': 'science/technology', 'text': 'Слишком часто используемое и нередко высмеиваемое правило третей — это простая рекомендация, которая создаёт динамизм, сохраняя при этом определённую долю порядка в изображении.'})
# №24 -- Процесс рассуждения:
# 1. ({'index_id': 1024, 'category': 'science/technology', 'text': 'Это не только подтверждает, что, по крайней мере, у некоторых динозавров были перья, что является уже широко распространённой теорией, но и предоставляет детали, которые обычно нельзя получить из окаменелых остатков, такие как цвет и трехмерную структуру.'})
# №25 -- Процесс рассуждения: В данном ({'index_id': 373, 'category': 'science/technology', 'text': 'Как бы меня притягивала гравитация Ио? Стоя на поверхности Ио, вы бы весили меньше, чем на Земле.'})
# №26 -- Процесс рассуждения:
# В текст ({'index_id': 1332, 'category': 'science/technology', 'text': 'NextGen — это система, которая, по заверению Федеральной авиационной администрации США, позволит самолетам летать по сокращенным маршрутам и ежегодно экономить миллионы галлонов топлива, а также снизить выбросы углерода.'})
# №27 -- Процесс рассуждения:
# Т ({'index_id': 1670, 'category': 'science/technology', 'text': 'Данные нейробиологии дают физические свидетельства для теоретического подхода к изучению сознания. Таким образом сужается область исследования, и оно становится гораздо более точным.'})
# №28 -- Процесс рассуждения:
# В данном ({'index_id': 61, 'category': 'science/technology', 'text': 'Во время своего двухчасового выступления он заявил: "Сегодня Apple собирается переосмыслить свой телефон. Мы войдём сегодня в историю."'})
# №29 -- Процесс рассуждения:
# 1. ({'index_id': 454, 'category': 'science/technology', 'text': 'У зум-объективов имеется следующий недостаток: они требуют более сложной фокусировки и большее количество линз для получения возможности использовать весь диапазон фокусных расстояний по сравнению с фикс-объективами.'})
# №30 -- Процесс рассуждения:
# 1. ({'index_id': 1234, 'category': 'science/technology', 'text': 'В контроллере, который выглядит как телевизионный пульт, используются два датчика, находящиеся рядом с телевизором пользователя, с помощью которых вычисляется его положение в трёхмерном пространстве.'})
# №31 -- Процесс рассуждения: В данном ({'index_id': 1025, 'category': 'science/technology', 'text': 'Учёные говорят, что оперение этого животного было сверху каштаново-коричневого цвета, а снизу — либо бледным, либо имело каротиноидную пигментацию.'})
# №32 -- Процесс рассуждения:
# 1. ({'index_id': 1254, 'category': 'science/technology', 'text': 'Исследователи университета сообщили, что эти два соединения вступают друг с другом в реакцию, образуя кристаллы, которые могут блокировать работу почек.'})
# №33 -- Приступим к анализу данного текста ({'index_id': 780, 'category': 'science/technology', 'text': 'Благодаря этому, разрешение почти в четыре раза больше, чем у 35-миллиметрового негатива (3136 кв. мм против 864).'})
# №34 -- Процесс рассуждения: В данном ({'index_id': 649, 'category': 'science/technology', 'text': 'Благодаря  связи по подводному оптиковолоконному кабелю с Европой и широкополосному спутнику, Гренландия имеет хорошую связь, 93% населения имеют доступ в интернет.'})
# №35 -- Процесс рассуждения: В данном ({'index_id': 917, 'category': 'science/technology', 'text': 'Одно из наиболее выдающихся приложений в этой категории — Google Translate, которое обеспечивает перевод в режиме офлайн после скачивания желаемых языковых данных.'})
# №36 -- Процесс рассуждения:
# В ({'index_id': 603, 'category': 'science/technology', 'text': 'У нее одна и та же молекулярная структура вне зависимости от того, газ это, жидкость или твердое вещество.'})
# №37 -- Процесс рассуждения: В данном ({'index_id': 1518, 'category': 'science/technology', 'text': 'Использование видеозаписи привело к важным открытиям в сфере интерпретации микровыражений  — движений лица длительностью несколько миллисекунд.'})
# №38 -- Процесс рассуждения:
# Т ({'index_id': 584, 'category': 'science/technology', 'text': 'Люди делают и используют линзы для увеличения на протяжении многих тысячелетий.'})
# №39 -- Процесс рассуждения:
# 1. ({'index_id': 1589, 'category': 'science/technology', 'text': 'Он, однако, не является единственным. Научные исследования также руководствуются экспериментированием (эксперимент — это проверка, используемая, чтобы исключить одну или более возможных гипотез), задаванием вопросов и проведением наблюдений.'})
# №40 -- Процесс рассуждения:
# В данном ({'index_id': 1558, 'category': 'science/technology', 'text': 'Со временем деревянные колёса были заменены на железные. В 1767 году появились первые рельсы, сделанные полностью из железа.'})
# №41 -- Процесс рассуждения:
# 1. ({'index_id': 922, 'category': 'science/technology', 'text': 'Большая часть карт подходит для звонков в любое место, но некоторые из карт предоставляют льготные тарифы на звонки в определенные страны.'})
# №42 -- Процесс рассуждения: В данном ({'index_id': 1981, 'category': 'science/technology', 'text': 'Большинство современных исследовательских телескопов — это огромные сооружения в удаленных местах с благоприятными атмосферными условиями.'})
# №43 -- Процесс рассуждения:
# 1. ({'index_id': 351, 'category': 'science/technology', 'text': 'Стальная игла плавает по воде из-за поверхностного натяжения.'})
# №44 -- Процесс рассуждения:
# В текст ({'index_id': 1429, 'category': 'science/technology', 'text': '35-ти миллиметровый формат на самом деле несколько сбивает с толку, он имеет ширину 36 мм и высоту 24 мм.'})
# №45 -- Процесс рассуждения: В данном ({'index_id': 578, 'category': 'science/technology', 'text': 'Клетки настолько существенны и важны для изучения жизни, что фактически их обычно называют "строительными кирпичиками жизни".'})
# №46 -- Процесс рассуждения:
# 1. ({'index_id': 905, 'category': 'science/technology', 'text': 'Провайдеры личных VPN (виртуальных частных сетей) — отличный способ обойти как политическую цензуру, так и коммерческую геофильтрацию по IP-адресу.'})
# №47 -- Процесс рассуждения:
# 1. ({'index_id': 264, 'category': 'science/technology', 'text': 'Станция сохраняла своё положение в пространстве до завершения выхода в открытый космос, несмотря на потерю гироскопа в начале миссии космической станции.'})
# №48 -- Процесс рассуждения:
# В данном ({'index_id': 628, 'category': 'science/technology', 'text': 'Люди с таким типом мышления имеют логическое мышление, могут запоминать шаблоны, решать проблемы и работать над научными тестами.'})
# №49 -- Процесс рассуждения:
# 1. ({'index_id': 1366, 'category': 'science/technology', 'text': 'Оцелоты любят поедать мелких животных. Если представится случай, они будут ловить обезьян, змей, грызунов и птиц. Почти все зверьки, на которых охотится оцелот, гораздо меньше него.'})
# №50 -- Процесс рассуждения:
# Т ({'index_id': 779, 'category': 'science/technology', 'text': 'Некоторые плёночные фотоаппараты среднего формата используют формат 6 на 6 сантиметров, а точнее негатив 56мм на 56 мм.'})
# №51 -- Процесс рассуждения:
# 1. ({'index_id': 1874, 'category': 'travel', 'text': 'Путешественникам настоятельно рекомендуется принимать во внимание любые риски, связанные с суровой погодой в их районе, поскольку они могут повлиять на любые планы поездки.'})
# №52 -- Процесс рассуждения: В данном ({'index_id': 1734, 'category': 'travel', 'text': 'Автобусы отправляются с межрайонной автостанции (за рекой) в течение всего дня, хотя большая часть, особенно направляющиеся на восток и в Джакар/Бумтанг, отбывают с 06:30 до 07:30.'})
# №53 -- Процесс рассуждения: В данном ({'index_id': 1840, 'category': 'travel', 'text': 'Они обеспечивают наезднику лучшую устойчивость, но могут быть проблемы с безопасностью, так как есть вероятность  застревания ноги.'})
# №54 -- Процесс рассуждения:
# 1. ({'index_id': 1919, 'category': 'travel', 'text': 'Большинство отдельных балтийских круизов включают продленную стоянку в российском Санкт-Петербурге.'})
# №55 -- Процесс рассуждения:
# В данном ({'index_id': 828, 'category': 'travel', 'text': 'Этот совет предполагает, что туристы не воруют, не вторгаются на чужую собственность, не принимают участие в деятельности нелегального рынка, не попрошайничают и не эксплуатируют других людей для собственной выгоды.'})
# №56 -- Процесс рассуждения:
# В зад ({'index_id': 818, 'category': 'travel', 'text': 'Перед тем, как вы отправитесь в путешествие, и во время него вам нужно учитывать множество вещей.'})
# №57 -- Процесс рассуждения:
# В данном ({'index_id': 978, 'category': 'travel', 'text': 'Во время дневной жары путешественники могут увидеть миражи, при которых создается иллюзия воды (или других вещей).'})
# №58 -- Приступим к анализу данного текста ({'index_id': 765, 'category': 'travel', 'text': 'Cемьи с детьми здесь можно увидеть редко, но некоторые хостелы разрешают им селится в отдельных номерах.'})
# №59 -- Процесс рассуждения: В зад ({'index_id': 1992, 'category': 'travel', 'text': 'Например, посещение замков в долине Луары, долине Рейна, прогулка на круизе по достопримечательностям Дуная, или путешествие на лодке по каналу Эри.'})
# №60 -- Процесс рассуждения:
# Тек ({'index_id': 823, 'category': 'travel', 'text': 'Может быть лучше пользоваться услугами агента, который часто бронирует путешествия подобные вашему.'})
# №61 -- Процесс рассуждения:
# 1. ({'index_id': 762, 'category': 'travel', 'text': 'Компания Couchsurfing учреждена в январе 2004 года. Поводом для ее основания стало то, что программисту Кейси Фентон удалось найти недорогой авиабилет в Исландию, но ему негде было там остановиться.'})
# №62 -- Процесс рассуждения: В данном ({'index_id': 932, 'category': 'travel', 'text': 'Как правило, требования и процедуры подачи документов на получение студенческой визы отличаются от требований и процедур для получения обычных туристических или деловых виз.'})
# №63 -- Процесс рассуждения:
# 1. ({'index_id': 678, 'category': 'travel', 'text': 'Каждая страна также имеет особые законы, предписывающие какие предметы должны находится в машине на случай экстренной ситуации.'})
# №64 -- Процесс рассуждения:
# 1. ({'index_id': 822, 'category': 'travel', 'text': 'Большинство агентств предпочитают заниматься самыми востребованными турами, но многие агенты специализируются на конкретных видах путешествий, ценовых сегментах или направлениях.'})
# №65 -- Процесс рассуждения: В данном ({'index_id': 1820, 'category': 'travel', 'text': 'Путешественники могут встретиться с животными-вредителями, которых они не видели в своих родных краях.'})
# №66 -- Процесс рассуждения:
# В данном ({'index_id': 1947, 'category': 'travel', 'text': 'Севернее посетите также великий Храм Фатимской Богоматери (усыпальница) — место всемирно известных явлений Девы Марии.'})
# №67 -- Процесс рассуждения:
# 1. ({'index_id': 1713, 'category': 'travel', 'text': 'Вы можете по Гома на бода-бода (мототакси). Обычная (местная) цена 500 конголезских франков за короткую поездку.'})
# №68 -- Процесс рассуждения:
# 1. ({'index_id': 731, 'category': 'travel', 'text': 'Тем, кто любит активный отдых, обязательно нужно совершить поход по коридору Си-ту-Скай.'})
# №69 -- Процесс рассуждения:
# Т ({'index_id': 1808, 'category': 'travel', 'text': 'Пешее сафари (которое также называют "исследование кустов", "хайкинг-сафари" или "пешая прогулка") состоит из похода продолжительностью от нескольких часов до нескольких дней.'})
# №70 -- Процесс рассуждения: В данном ({'index_id': 1929, 'category': 'travel', 'text': 'Единственный способ быстрее разобраться с ним — это отправить его как зарегистрированный багаж. Регламент авиакомпании не позволяет отправлять багаж без пассажира, поэтому тут нужно ваше участие.'})
# №71 -- Процесс рассуждения: Этот текст ({'index_id': 131, 'category': 'travel', 'text': 'Дополнительные 300 единиц увеличивают до 1300 общее количество вагонов, которые планируется приобрести, чтобы облегчить проблему чрезмерной скученности.'})
# №72 -- Процесс рассуждения:
# Тек ({'index_id': 814, 'category': 'travel', 'text': 'Семьям с маленькими детьми могут понадобиться дополнительные приготовления, но день на открытом воздухе с легкостью можно провести даже с малолетними детьми и детьми дошкольного возраста.'})
# №73 -- Процесс рассуждения:
# В данном ({'index_id': 1799, 'category': 'travel', 'text': 'Все, кто собирается ехать по высокоширотной области или по горным перевалам, должны учитывать возможность снега, льда или морозов.'})
# №74 -- Процесс рассуждения:
# В данном ({'index_id': 1715, 'category': 'travel', 'text': 'Сегодня Томбукту — это обнищалый город, но его репутация привлекает сюда туристов, и в нем есть аэропорт.'})
# №75 -- Процесс рассуждения: В данном ({'index_id': 1801, 'category': 'travel', 'text': 'Во время метели достаточное количество снега для того, чтобы можно было застрять, может выпасть за очень короткий промежуток времени.'})
# №76 -- Процесс рассуждения:
# 1. ({'index_id': 957, 'category': 'travel', 'text': 'Если вы хотите полностью облететь мир в южном полушарии, выбор рейсов и направлений является ограниченным в связи с недостатком трансокеанских маршрутов.'})
# №77 -- Процесс рассуждения: В данном ({'index_id': 953, 'category': 'travel', 'text': 'Такие авиакомпании, как Emirates, Etihad Airways, Qatar Airways и Turkish Airlines значительно расширили перечень их услуг для Африки и предлагают рейсы во многие крупные города Африки по конкурентоспособным ценам в сравнении с другими европейскими авиакомпаниями.'})
# №78 -- Процесс рассуждения:
# 1. ({'index_id': 1334, 'category': 'travel', 'text': 'К Уэмбли не запущено дополнительного транспорта, там не будут останавливаться наземные поезда, кроме того, на поверхности отсутствуют парковки и перехватывающие стоянки.'})
# №79 -- Процесс рассуждения:
# 1. ({'index_id': 931, 'category': 'travel', 'text': 'Как правило, для пребывания в любой зарубежной стране на протяжении длительного периода времени потребуется предварительное получение визы.'})
# №80 -- Процесс рассуждения:
# В ({'index_id': 855, 'category': 'travel', 'text': 'Вагоны MetroPlus и Metro имеются в каждом поезде. Вагоны первого вида всегда находятся в конце поезда, ближайшем к Кейптауну.'})
# №81 -- Процесс рассуждения: В данном ({'index_id': 1607, 'category': 'travel', 'text': 'Каждый является членом общества и использует транспортные системы. Практически каждый жалуется на эти систем.'})
# №82 -- Приступим к анализу данного текста ({'index_id': 2004, 'category': 'travel', 'text': 'Так как эти районы являются малонаселенными, и, как следствие, световое загрязнение часто не является проблемой, вы также сможете наслаждаться звездами.'})
# №83 -- Процесс рассуждения:
# 1) ({'index_id': 677, 'category': 'travel', 'text': 'Требования к визам и их стоимость разные во всех странах и зависят от вашей страны.'})
# №84 -- Процесс рассуждения:
# Т ({'index_id': 1932, 'category': 'travel', 'text': 'Как правило, нет смысла даже искать скидки на бизнес-класс или первый класс для прямых полетов из A в Б.'})
# №85 -- Процесс рассуждения:
# Т ({'index_id': 846, 'category': 'travel', 'text': 'Метание бумеранга является популярным умением. Множество туристов хотят научиться метать бумеранг.'})
# №86 -- Процесс рассуждения:
# В данном ({'index_id': 960, 'category': 'travel', 'text': 'Данный рейс не является единственным вариантом, если вы желаете не включать южную часть Тихого океана и западное побережье Южной Америки. (см. ниже)'})
# №87 -- Процесс рассуждения:
# 1. ({'index_id': 662, 'category': 'travel', 'text': 'Сан-Франциско развил крупную туристическую инфраструктуру с большим количеством отелей, ресторанов и первоклассных конференц-центров.'})
# №88 -- Процесс рассуждения:
# В ({'index_id': 942, 'category': 'travel', 'text': 'Волонтёрство во время путешествий — это отличный способ изменить мир к лучшему, но это гораздо большее, чем просто помощь.'})
# №89 -- Процесс рассуждения:
# Тек ({'index_id': 1894, 'category': 'travel', 'text': 'Для людей может быть неожиданным, что терпение и понимание необходимо проявлять и к путешественникам, вернувшимся домой.'})
# №90 -- Процесс рассуждения: В данном ({'index_id': 956, 'category': 'travel', 'text': 'Не забудьте учесть добавочные расходы на дополнительные визы, налоги на выезд, наземный транспорт и т. д. для всех тех мест за пределами Африки.'})
# №91 -- Процесс рассуждения:
# В данном ({'index_id': 1172, 'category': 'politics', 'text': 'Некоторая часть жителей Бишкека обвинила митингующих с юга в беззаконии.'})
# №92 -- Процесс рассуждения:
# 1. ({'index_id': 433, 'category': 'politics', 'text': 'Современные участки территории Бельгии в прошлом были частью Люксембурга, но после Бельгийской революции 1830-х годов стали бельгийскими.'})
# №93 -- Процесс рассуждения:
# В данном ({'index_id': 1162, 'category': 'politics', 'text': 'Начиная с 1988 года урны для избирательных бюллетеней должны быть прозрачными, чтобы избиратели и наблюдатели могли убедиться в том, что в начале голосования внутри нет конвертов и что к ним не добавлены какие-либо другие конверты, кроме конвертов тех людей, которых допустили к участию в голосовании и голоса которых подсчитали надлежащим образом.'})
# №94 -- Процесс рассуждения:
# В текст ({'index_id': 1320, 'category': 'politics', 'text': 'Исполняющая обязанности премьер-министра Джулия Гиллард во время федеральной избирательной кампании 2010 года высказала мнение о том, что Австралия должна стать республикой после правления королевы Елизаветы II.'})
# №95 -- Процесс рассуждения:
# 1) ({'index_id': 181, 'category': 'politics', 'text': 'Ирландское правительство подчеркивает срочную необходимость парламентского законодательства, чтобы разрешить ситуацию.'})
# №96 -- Процесс рассуждения:
# Тек ({'index_id': 963, 'category': 'politics', 'text': 'На отношения между Арменией и Азербайджаном по-прежнему негативно влияют дипломатические споры в отношении данного региона.'})
# №97 -- Процесс рассуждения: В данном ({'index_id': 1068, 'category': 'politics', 'text': 'Премьер-министр Стивен Харпер согласился отослать "Закон о чистом воздухе" на рассмотрение общепартийного комитета до второго чтения. Этому предшествовала 25-минутная встреча с лидером НДП Джеком Лейтоном в ОУП во вторник.'})
# №98 -- Процесс рассуждения:
# В данном ({'index_id': 284, 'category': 'politics', 'text': 'В прошлом месяце, когда страна подписала соглашение ACTA, в Польше прошли значительные протесты. В результате них правительство Польши решило пока не ратифицировать данный документ.'})
# №99 -- При рассмотрении текста я виж ({'index_id': 1868, 'category': 'politics', 'text': 'В информационных сообщениях всего лишь кратко описана политическая ситуация в одной стране.'})
# №100 -- Процесс рассуждения:
# В данном ({'index_id': 1015, 'category': 'politics', 'text': 'Во время выборов 1976 года он консультировал Картера по вопросам внешней политики. Затем с 1977 по 1981 год он работал советником по национальной безопасности, сменив на этом посту Генри Киссинджера.'})
# №101 -- Процесс рассуждения: В данном ({'index_id': 1023, 'category': 'politics', 'text': 'Кроме того, Турция займет главную роль в вопросе охраны пойманных боевиков ИГИЛ, которых, согласно заявлению, европейские государства не согласились возвращать домой.'})
# №102 -- Процесс рассуждения:
# 1. ({'index_id': 1545, 'category': 'politics', 'text': 'Однако эти планы стали неактуальны практически за ночь, когда около 800 000 солдат из советской Красной армии образовали Белорусский и Украинский фронты после захвата восточных регионов Польши в нарушение Рижского мирного соглашения, Советско-Польского пакта о ненападении, и других международных соглашений, двусторонних и многосторонних.'})
# №103 -- Процесс рассуждения: В данном ({'index_id': 300, 'category': 'politics', 'text': 'Следуя процедуре, совместная резолюция обеих палат будет рассмотрена следующими избранными законодателями вновь в 2015 или 2016 году для продолжения процесса.'})
# №104 -- Процесс рассуждения: В данном ({'index_id': 1565, 'category': 'politics', 'text': 'После принятия Конгрессом 4 июля, рукописный проект, подписанный председателем Конгресса Джоном Хэнкоком и секретарем Чарльзом Томсоном, был отправлен за несколько кварталов в печатную мастерскую Джона Данлапа.'})
# №105 -- Процесс рассуждения:
# - Т ({'index_id': 8, 'category': 'politics', 'text': 'Сразу после 11:00 протестующие перекрыли движение в северном направлении по Уайтхоллу.'})
# №106 -- Процесс рассуждения:
# В данном ({'index_id': 489, 'category': 'politics', 'text': 'Однако в июне 1956 года обещания Хрущёва были подвергнуты испытанию, когда беспорядки в Польше, где рабочие протестовали против нехватки продовольствия и урезания зарплат, переросли в общий протест против коммунизма.'})
# №107 -- Процесс рассуждения: В данном ({'index_id': 1543, 'category': 'politics', 'text': 'Ей предстояло продлиться следующие 40 лет. В ней воевали по-настоящему, используя опосредованные армии, на полях сражений от Африки до Азии, в Афганистане, на Кубе и во многих других местах мира.'})
# №108 -- Процесс рассуждения: В текст ({'index_id': 1296, 'category': 'politics', 'text': 'В прошлом месяце президентская комиссия рекомендовала предыдущему Временному избирательному совету уйти в отставку в качестве части пакета мер для движения страны к новым выборам.'})
# №109 -- Процесс рассуждения:
# 1. ({'index_id': 1289, 'category': 'politics', 'text': 'Другие затронутые темы, как сообщается, включают будущее состояние Иерусалима, который является священным для обоих народов, и проблему долины реки Иордан.'})
# №110 -- Процесс рассуждения: В данном ({'index_id': 1413, 'category': 'politics', 'text': 'У него также не было полномочий отменять налоговое законодательство и тарифы штатов.'})
# №111 -- Процесс рассуждения:
# Т ({'index_id': 1161, 'category': 'politics', 'text': 'Законы Франции о выборах довольно строго систематизируют процедуры.'})
# №112 -- При рассмотрении данного текста становится оч ({'index_id': 1067, 'category': 'politics', 'text': 'Спустя неделю после поражений на промежуточных выборах, Буш сообщил публике о расширении торговли с Азией.'})
# №113 -- Приступим к анализу текста: ({'index_id': 1440, 'category': 'politics', 'text': 'Эта стратегия доказала свою эффективность, отрезав жизненно важные военные и гражданские поставки, хотя эта блокада нарушала принятые повсеместно международные законы, изложенные в нескольких международных соглашениях за последние двести лет.'})
# №114 -- Процесс рассуждения:
# В ({'index_id': 1937, 'category': 'politics', 'text': 'Несмотря на безуспешность политических переговоров, экономические связи между этими двумя частями Молдовы были восстановлены.'})
# №115 -- Процесс рассуждения: В данном ({'index_id': 168, 'category': 'politics', 'text': 'Сопровождаемый этими должностными лицами, он заверил жителей Техаса, что меры по защите безопасности населения принимаются.'})
# №116 -- Приступим к анализу текста:
#  ({'index_id': 1055, 'category': 'politics', 'text': 'Либеральная критика усилий по восстановлению сосредоточивалась на том, что контракты на восстановительные работы отдавались предположительно имеющим связи с правительством.'})
# №117 -- Процесс рассуждения:
# В данном ({'index_id': 1319, 'category': 'politics', 'text': 'Из 1400 человек, опрошенных в преддверии федеральных выборов 2010 года, число тех, кто выступает против того, чтобы Австралия стала республикой, выросло с 2008 года на 8 процентов.'})
# №118 -- Процесс рассуждения: В данном ({'index_id': 92, 'category': 'politics', 'text': 'Согласно заявлению дипломатов, в конституции Афганистана было обнаружено достаточно неконкретных положений, позволяющих признать следующий тур ненужным.'})
# №119 -- Процесс рассуждения:
# В данном ({'index_id': 1189, 'category': 'politics', 'text': 'После того, как стали известны результаты, Гингрич похвалил Санторума, но грубо высказался о Ромни, от имени которого в Айове транслировалась негативная информация против Гингрича.'})
# №120 -- Процесс рассуждения:
# В данном ({'index_id': 1295, 'category': 'politics', 'text': 'Это пятый CEP Мартейи за четыре года.'})
# №121 -- Процесс рассуждения:
# В ({'index_id': 1323, 'category': 'sports', 'text': 'Олимпийский золотой медалист должен был участвовать в заплыве на 100 и 200 м в вольном стиле и в трёх эстафетах на Играх Содружества, но из-за его жалоб его физическая форма теперь находится под сомнением.'})
# №122 -- Процесс рассуждения: В данном ({'index_id': 308, 'category': 'sports', 'text': 'Когда Сайто скончался, он был не только в прошлом олимпийским чемпионом и чемпионом мира, но и руководителем комиссии по обучению, входящей во Всеяпонскую федерацию дзюдо.'})
# №123 -- Процесс рассуждения:
# 1. ({'index_id': 215, 'category': 'sports', 'text': 'Международный олимпийский комитет проголосовал за включение этих видов на заседании исполнительного комитета сегодня в Берлине. Регби, а конкретнее регби-юнион, и гольф выбрали вместо пяти других видов спорта, чтобы рассмотреть их участие в программе Олимпийских игр.'})
# №124 -- Процесс рассуждения:
# 1. ({'index_id': 1748, 'category': 'sports', 'text': 'Крупнейший турнир года проходит в декабре на полях для игры в поло в Лас Каньитас.'})
# №125 -- Процесс рассуждения:
# В данном ({'index_id': 6, 'category': 'sports', 'text': 'После переезда в столицу Каталонии  Видаль провел за клуб 49 матчей.'})
# №126 -- При чтении текста я обратил внимание ({'index_id': 552, 'category': 'sports', 'text': 'Поддержка здорового энергетического баланса, соблюдение эффективных привычек поддержания водного баланса и понимание различных аспектов использования пищевых добавок могут помочь спортсменам улучшить свои показатели и увеличить удовольствие от спорта.'})
# №127 -- Процесс рассуждения:
# 1. ({'index_id': 159, 'category': 'sports', 'text': 'На 3-м месте — Хэмлин, который отстает на двадцать очков, но опережает на пять Бойера. Кейн и Трукс-младший занимают 5-е и 6-е места соответственно, набрав по 2220 и 2207 очков.'})
# №128 -- Процесс рассуждения: В данном ({'index_id': 11, 'category': 'sports', 'text': 'Рекорд Надала в схватках один на один с канадцем —  7–2.'})
# №129 -- Процесс рассуждения:
# В ({'index_id': 184, 'category': 'sports', 'text': 'Ранее тем же днем Харке тренировался во время предсезонной подготовки в Коверчано в Италии. Он оставался в отеле команды перед запланированным на воскресенье матчем против "Болоньи".'})
# №130 -- Процесс рассуждения:
# В данном ({'index_id': 1335, 'category': 'sports', 'text': 'Опасения по поводу отсутствия транспорта вызвали предположение о том, что игру, возможно, придётся проводить за закрытыми дверями без болельщиков.'})
# №131 -- Процесс рассуждения:
# 1. ({'index_id': 1317, 'category': 'sports', 'text': 'Вот, что сказал Томми Дример: "Луна стала первой Королевой Экстрима. Она была моим первым менеджером. Луна ушла из жизни в ночь двух лун. Это такое уже уникальное событие, как и она сама. Сильная женщина".'})
# №132 -- Процесс рассуждения:
# 1. ({'index_id': 1200, 'category': 'sports', 'text': 'Польский лыжник с нарушением зрения Мацей Крезель и спортсмен-ведущий Анна Огаржинска финишировали тринадцатыми в супергиганте. Южнокорейский лыжник Пак Чон Сок финишировал двадцать четвёртым в супергиганте среди мужчин в положении сидя.'})
# №133 -- Процесс рассуждения: В данном ({'index_id': 1750, 'category': 'sports', 'text': 'Чтобы узнать новости о матчах поло и о том, где купить на них билеты, загляните на сайт Аргентинской ассоциации поло.'})
# №134 -- Процесс рассуждения:
# В ({'index_id': 1149, 'category': 'sports', 'text': 'Матчи начались в 10:00 при прекрасной погоде, и если не считать моросящий утренний дождь, который быстро прошёл, это был идеальный день для регби-7.'})
# №135 -- Процесс рассуждения: Этот текст ({'index_id': 1199, 'category': 'sports', 'text': 'Арли Веласкес из Мексики финишировал пятнадцатым среди мужчин в супергиганте в положении сидя. Новозеландец Адам Холл финишировал девятым среди мужчин в супергиганте в положении стоя.'})
# №136 -- Процесс рассуждения:
# 1. ({'index_id': 1177, 'category': 'sports', 'text': 'Финальный матч сезона будет проведён в Эллис Парке в Йоханесбурге на следующей неделе, когда Springboks сыграет с Австралией.'})
# №137 -- Процесс рассуждения:
# 1. ({'index_id': 1853, 'category': 'sports', 'text': 'При хороших условиях вы сможете преодолевать несколько бо́льшие расстояния, чем при передвижении пешком, но такую скорость на беговых лыжах вы сможете развить только в крайне редких случаях, когда у вас нет тяжёлого рюкзака и есть проложенная лыжня.'})
# №138 -- Приступим к анализу текста: ({'index_id': 158, 'category': 'sports', 'text': 'Отстав на семь очков, Джонсон на втором месте с результатом в 2243 очка.'})
# №139 -- Приступим к анализу текста: ({'index_id': 809, 'category': 'sports', 'text': 'Каньонинг (или спуск по каньону) представляет собой спуск на дно каньона, которое может быть как сухим, так и полным воды.'})
# №140 -- Процесс рассуждения:
# В данном ({'index_id': 1062, 'category': 'sports', 'text': 'Робин Утхаппа  набрал рекордное количество очков в иннинге: 70 ранов за всего 41 подачу, отбил 11 четвёрок и 2 шестёрки.'})
# №141 -- Процесс рассуждения:
# 1. ({'index_id': 1417, 'category': 'sports', 'text': 'Зимний спорт популярнее всего в северных регионах. Жители Италии из этих регионов участвуют в международных соревнованиях и Олимпиадах.'})
# №142 -- Мой процесс рассуждения: В данном ({'index_id': 78, 'category': 'sports', 'text': 'Маручидор финишировал самым первым, обогнав Нусу, занявшего второе место, на шесть очков.'})
# №143 -- Приступим к анализу данного текста ({'index_id': 1238, 'category': 'sports', 'text': 'Михаэль Шумахер завершил гонку вскоре после Алонсо в следствие повреждения подвески, полученного во время многочисленных попыток обгона в ходе гонки.'})
# №144 -- Процесс рассуждения:
# 1. ({'index_id': 551, 'category': 'sports', 'text': 'Сама по себе практика правильного питания не приведет к высочайшим результатам, но она способна значительно повлиять на общее состояние здоровья молодых спортсменов.'})
# №145 -- Процесс рассуждения: В данном ({'index_id': 1324, 'category': 'sports', 'text': 'Он не смог принять препараты, необходимые для облегчения боли, так как они запрещены в Играх.'})
# №146 -- Моё рассуждение:
# Тем ({'index_id': 1584, 'category': 'health', 'text': 'Исследования показали, что от рассеянного склероза страдает в два раза больше женщин, чем мужчин.'})
# №147 -- Процесс рассуждения:
# 1. ({'index_id': 803, 'category': 'health', 'text': 'Нелегальные спиртные напитки могут содержать различные опасные примеси, включая метиловый спирт, который в небольших дозах может вызвать слепоту или даже смерть.'})
# №148 -- Процесс рассуждения:
# В данном ({'index_id': 564, 'category': 'health', 'text': 'Только эффект катастрофических настроений, а не депрессия или страх, были условием регулярных еженедельно структурированных сессий физической активности.'})
# №149 -- Процесс рассуждения: В данном ({'index_id': 1482, 'category': 'health', 'text': 'Массовое владение автомобилями также приводит к увеличению числа ДТП на дорогах, что приводит к изобретению в здравоохранении новых методов лечения полученных травм.'})
# №150 -- Процесс рассуждения:
# 1. ({'index_id': 1, 'category': 'health', 'text': 'Ведущие исследователи утверждают, что он может помочь в раннем выявлении рака, туберкулеза, ВИЧ и малярии у пациентов в странах с низким уровнем дохода, где показатели выживаемости при таких болезнях, как рак молочной железы, могут быть в два раза ниже, чем в более богатых странах.'})
# №151 -- При чтении текста становится ясно ({'index_id': 998, 'category': 'health', 'text': 'Согласно предупреждению доктора Эхуда Ура (Ehud Ur), профессора медицины в Университете Дэлхаузи в Галифаксе (Новая Шотландия) и председателя клинико-научного отдела Канадской диабетической ассоциации, исследования все еще находятся на начальной стадии.'})
# №152 -- Приступим к анализу текста: ({'index_id': 511, 'category': 'health', 'text': 'Эти дети склонны попадать во многие неприятности, потому что они "вовлекаются в виды поведения с повышенным риском, участвуют в драках и бросают вызов властям" для того, чтобы стимулировать свой мозг, поскольку их мозг не может быть стимулирован нормальными методами.'})
# №153 -- Процесс рассуждения:
# 1. ({'index_id': 138, 'category': 'health', 'text': 'Люди могут пострадать, вдыхая загрязненную воду, попавшую в воздух с ветром и волнами.'})
# №154 -- Процесс рассуждения:
# В данном ({'index_id': 520, 'category': 'health', 'text': 'Некоторые люди считают, что достаточно частое переживание многочисленных осознанных, искусственно вызванных сновидений может быть очень изнурительным.'})
# №155 -- Процесс рассуждения:
# Тек ({'index_id': 1226, 'category': 'health', 'text': 'На данный момент Потро была оказана медицинская помощь для его плеча и он сумел вернуться к игре.'})
# №156 -- Процесс рассуждения: В данном ({'index_id': 1526, 'category': 'health', 'text': 'Более того, невыполнение этого приведёт к таким серьёзным последствиям, как замедление роста, недоедание и, в конечном счёте, смерть.'})
# №157 -- Процесс рассуждения:
# В данном ({'index_id': 1153, 'category': 'health', 'text': 'Официальные представители властей Амстердама и музея Анны Франк заявляют, что дерево заражено грибком и представляет общественную опасность, так как есть непосредственная угроза его падения.'})
# №158 -- Приступим к анализу текста: ({'index_id': 1208, 'category': 'health', 'text': 'В больнице был соблюден протокол инфекционного контроля, включая отдельное содержание пациента, чтобы предотвратить возможное заражение других пациентов.'})
# №159 -- Процесс рассуждения:
# 1. ({'index_id': 1204, 'category': 'health', 'text': 'Гаитянский Институт Справедливости и Демократии сослался на независимое исследование, которое предполагает, что непальский миротворческий батальон ООН непреднамеренно завёз заболевание в Гаити.'})
# №160 -- Процесс рассуждения: В зад ({'index_id': 1822, 'category': 'health', 'text': 'Инфекционные болезни сами по себе или опасные животные, могущие нанести повреждения или привести к смерти человека, как правило, не считаются вредителями.'})
# №161 -- Приступим к анализу текста: ({'index_id': 510, 'category': 'health', 'text': 'Детям с СДВГ тяжело сосредотачиваться на таких вещах, как работа в школе, но они могут концентрироваться на вещах, которые им нравиться делать, таких как игры, просмотр их любимых мультфильмов или написание предложений без знаков пунктуации.'})
# №162 -- Процесс рассуждения: В данном ({'index_id': 1097, 'category': 'health', 'text': 'За один год инфицированный человек может заразить от 10 до 15 человек при близком контакте.'})
# №163 -- Процесс рассуждения:
# В данном ({'index_id': 1129, 'category': 'health', 'text': 'Когда драка прекратилась, после того как раненые были доставлены в больницу, еще около 40 заключенных остались во дворе и отказались возвращаться в свои камеры.'})
# №164 -- Процесс рассуждения:
# 1. ({'index_id': 495, 'category': 'health', 'text': 'Император Август начал набирать врачей, которые даже сформировали первый римский медицинский корпус, использовавшийся после сражений.'})
# №165 -- Процесс рассуждения: В данном ({'index_id': 1279, 'category': 'health', 'text': 'Однако водитель получил серьезные травмы головы.'})
# №166 -- Процесс рассуждения:
# 1. ({'index_id': 997, 'category': 'health', 'text': '"Теперь у нас есть четырёхмесячные мыши, у которых больше нет диабета", — добавил он.'})
# №167 -- Процесс рассуждения:
# В данном ({'index_id': 1576, 'category': 'health', 'text': 'Может быть трудно сразу выявить пероральное отравление. Такие симптомы, как рвота, слишком общие для быстрой постановки диагноза.'})
# №168 -- Процесс рассуждения:
# 1. ({'index_id': 1187, 'category': 'entertainment', 'text': 'В результате актёры курят косяки с марихуаной на сцене, и сам театр поощряет публику присоединиться.'})
# №169 -- Приступим к анализу данного текста ({'index_id': 1221, 'category': 'entertainment', 'text': 'Группа Aerosmith отменила оставшиеся концерты в своем турне.'})
# №170 -- Процесс рассуждения:
# 1. ({'index_id': 1791, 'category': 'entertainment', 'text': 'Если вы хотите находиться рядом со сценой, вам нужно приехать заранее, чтобы найти место для кемпинга вблизи от музыки.'})
# №171 -- Процесс рассуждения: В данном ({'index_id': 777, 'category': 'entertainment', 'text': 'Существует множество разных форматов пленки, используемых уже на протяжении долгих лет. Стандартная 35-миллиметровая пленка (негатив 36 на 24 мм) — наиболее распространенная.'})
# №172 -- Процесс рассуждения:
# Т ({'index_id': 668, 'category': 'entertainment', 'text': 'Хотя это и очень распространенный тип сделки, он запрещен правилами Disney: билеты не подлежат передаче другому лицу.'})
# №173 -- Приступим к анализу текста: ({'index_id': 38, 'category': 'entertainment', 'text': 'Каждый эпизод шоу будет посвящен теме в определенной книге и потом станет исследовать эту тему с помощью разнообразных историй.'})
# №174 -- Процесс рассуждения: В данном ({'index_id': 1058, 'category': 'entertainment', 'text': 'В различных местах Рима были установлены большие телевизионные экраны, с помощью которых люди могли наблюдать за церемонией.'})
# №175 -- Процесс рассуждения:
# 1. ({'index_id': 414, 'category': 'entertainment', 'text': 'Софокл и Аристофан по-прежнему являются популярными драматургами, и их пьесы считаются одними из величайших произведений мировой литературы.'})
# №176 -- Процесс рассуждения: В данном ({'index_id': 39, 'category': 'entertainment', 'text': 'Каждое шоу также даст рекомендацию по поводу книги, которую стоит искать детям, когда они пойдут в библиотеку.'})
# №177 -- Процесс рассуждения: В данном ({'index_id': 480, 'category': 'entertainment', 'text': 'Для получения более громкого звука на аккордеоне, мехи используются с большим давлением или скоростью.'})
# №178 -- При чтении текста я вижу ({'index_id': 1896, 'category': 'entertainment', 'text': 'Пирамиды можно увидеть в темноте, и вы также можете увидеть их в тишине перед началом шоу.'})
# №179 -- Процесс рассуждения: В зад ({'index_id': 1602, 'category': 'entertainment', 'text': 'Среди примеров активного отдыха на объекте – охота, рыбная ловля, фотографирование, наблюдение за птицами, посещение парков и изучение информации об экосистеме.'})
# №180 -- При чтении текста я注意到，S ({'index_id': 1898, 'category': 'entertainment', 'text': 'Сфинкс выступает в качестве фона и рассказчика длинной истории.'})
# №181 -- Процесс рассуждения:
# В данном ({'index_id': 1797, 'category': 'entertainment', 'text': 'В них обычно предлагается особая еда, напитки и развлечения, чтобы гости оставались в хорошем настроении и не покидали заведения.'})
# №182 -- Процесс рассуждения: В данном ({'index_id': 344, 'category': 'entertainment', 'text': 'Глобальная организация уже сейчас вещает на английском и японском, а вскоре еще запустит ТВ-передачи, передачи в интернете и на мобильных устройствах на испанском, итальянском и корейском языках.'})
# №183 -- Процесс рассуждения: В данном ({'index_id': 1209, 'category': 'entertainment', 'text': 'До "Симпсонов" Саймон работал на различных должностях над несколькими передачами.'})
# №184 -- Процесс рассуждения:
# Тек ({'index_id': 1235, 'category': 'entertainment', 'text': 'Посредством движения устройства в воздухе игроки смогут управлять действиями и движениями в видеоиграх.'})
# №185 -- Процесс рассуждения: Этот текст ({'index_id': 309, 'category': 'entertainment', 'text': 'На вечеринке по случаю празднования первой годовщины пары, свадьба которой состоялась в прошлом году, присутствовало не меньше 100 человек.'})
# №186 -- Процесс рассуждения:
# В ({'index_id': 1020, 'category': 'entertainment', 'text': 'Две песни из фильма — Audition (The Fools Who Dream) и City of Stars, попали в номинацию лучшая авторская песня. Студия Lionsgate попала в 26 номинаций — больше, чем любая другая студия.'})
# №187 -- Процесс рассуждения: В данном ({'index_id': 1648, 'category': 'geography', 'text': 'Толщина коры составляет около 70 км под океанами и 100 км – под материками.'})
# №188 -- Приступим к анализу данного текста ({'index_id': 1690, 'category': 'geography', 'text': 'Далее на юг расположен Ниагарский водопад, а север является вотчиной нетронутой природной красоты Мускоки и прилегающих областей.'})
# №189 -- Процесс рассуждения:
# Т ({'index_id': 1903, 'category': 'geography', 'text': 'Земля Элсуэрта — область к югу от Антарктического полуострова, омываемая морем Беллинсгаузена.'})
# №190 -- Приступим к анализу данного текста ({'index_id': 891, 'category': 'geography', 'text': 'Шоссе Мак-Мердо — Южный полюс — это 1600-километровый путь от станции Мак-Мердо у моря Росса до полюса.'})
# №191 -- Процесс рассуждения: В данном ({'index_id': 706, 'category': 'geography', 'text': 'У северной границы Мачу-Пикчу возвышается эта крутая гора, которую часто можно увидеть на заднем плане на многих фотографиях руин.'})
# №192 -- Процесс рассуждения:
# 1. ({'index_id': 117, 'category': 'geography', 'text': 'Энцелад — самый светоотражающий объект Солнечной системы, он отражает около 90 процентов падающего на него солнечного света.'})
# №193 -- Процесс рассуждения: В зад ({'index_id': 1459, 'category': 'geography', 'text': 'Не видно ничего кроме чистого прекрасного неба над головой и множества окружающих гор. Из глубины пещеры можно видеть и слышать лишь очень малую часть этого мира.'})
# №194 -- Процесс рассуждения: В данном ({'index_id': 400, 'category': 'geography', 'text': 'Теперь о Японии. Япония была островным государством, так же как и Британия.'})
# №195 -- При чтении текста я обратил внимание ({'index_id': 139, 'category': 'geography', 'text': 'На своём пике тропический циклон Гону, название которого на языке Мальдивских островов означает "сумка из пальмовых листьев", достигал силы ветра в 240 километров в час (149 миль в час).'})
# №196 -- Процесс рассуждения: В данном ({'index_id': 429, 'category': 'geography', 'text': 'Территория Турции, включая озёра, занимает 783 562 кв. км (300 948 кв. миль), из которых 755 688 кв. км (291 773 кв. миль) находится в юго-западной Азии, а 23 764 кв. км (9 174 кв. миль) — в Европе.'})
# №197 -- Процесс рассуждения:
# В данном ({'index_id': 1900, 'category': 'geography', 'text': 'На открытые в 1819 году Южные Шетландские острова претендуют несколько стран. На этих островах расположено больше всего баз и в 2020 году шестнадцать были действующими.'})
# №198 -- Процесс рассуждения:
# В данном ({'index_id': 1765, 'category': 'geography', 'text': 'Апиа – столица Самоа. Город расположен на острове Уполу и имеет население чуть менее 40 000 жителей.'})
# №199 -- Процесс рассуждения:
# В ({'index_id': 326, 'category': 'geography', 'text': 'Шторм пока далеко от берега, поэтому все еще тяжело оценить его возможное влияние на страны Карибского бассейна и США.'})
# №200 -- Процесс рассуждения:
# - Т ({'index_id': 1649, 'category': 'geography', 'text': 'Она тоньше под лунными морями и толще под нагорьями.'})
# №201 -- Процесс рассуждения:
# 1. ({'index_id': 1731, 'category': 'geography', 'text': 'Эти леса не просто мангровые болота — к ним также относятся некоторые из последних оставшихся могучих джунглей, которые когда-то покрывали Гангскую равнину.'})
# №202 -- Процесс рассуждения: В данном ({'index_id': 289, 'category': 'geography', 'text': 'Международная карта землетрясений Геологической службы Соединённых Штатов не отображала землетрясений в Исландии за неделю до этого.'})
# №203 -- Процесс рассуждения:
# 1) ({'index_id': 1457, 'category': 'geography', 'text': 'Пещера располагается на вершине горы к северу от Мекки и полностью изолирована от остального мира.'})

# %%
test_clarification_set_for_llm = test_clarification_set.map(
    lambda it: prepare_message_for_llm(
        it['text'],
        examples_by_categories,
        prompt_system_2,
        prompt_user_2
    )
)
# Out:
# Map:   0%|          | 0/204 [00:00<?, ? examples/s]

# %%
test_clarification_pred = list(map(
    lambda x: LLM_PIPELINE(x, max_new_tokens=10)[0]['generated_text'],
    tqdm(test_clarification_set_for_llm['message_for_llm'])
))
test_clarification_true = test_clarification_set['category']
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]

# %%
combine_cnt = 0
for i in test_clarification_idx:
    test_pred[i] = test_clarification_pred[combine_cnt]
    combine_cnt += 1

# %%
print(m.classification_report(
    y_true=test_true,
    y_pred=[x[-1]['content'] for x in test_pred])
)
# Out:
#                                                     precision    recall  f1-score   support
#
#                                            culture       0.00      0.00      0.00         0
#                                          education       0.00      0.00      0.00         0
#                                      entertainment       0.85      0.58      0.69        19
#                                          geography       0.80      0.71      0.75        17
#                                             health       0.81      0.77      0.79        22
#                                             nature       0.00      0.00      0.00         0
#                                           politics       1.00      0.80      0.89        30
#                                 science/technology       0.90      0.90      0.90        51
#                                             sports       1.00      0.68      0.81        25
#                                             travel       0.64      0.93      0.76        40
#                                            weather       0.00      0.00      0.00         0
# weather_conditions
#
# Ваш ответ не соответствует тем       0.00      0.00      0.00         0
#
#                                           accuracy                           0.80       204
#                                          macro avg       0.50      0.45      0.47       204
#                                       weighted avg       0.85      0.80      0.82       204

# %%
test_pred_norm = list(map(
    lambda it: process.extractOne(it[-1]['content'], list_of_categories, scorer=fuzz.token_sort_ratio)[0],
    test_pred
))

# %%
print(m.classification_report(
    y_true=test_true,
    y_pred=test_pred_norm)
)
# Out:
#                     precision    recall  f1-score   support
#
#      entertainment       0.79      0.58      0.67        19
#          geography       0.80      0.71      0.75        17
#             health       0.74      0.77      0.76        22
#           politics       1.00      0.80      0.89        30
# science/technology       0.90      0.90      0.90        51
#             sports       1.00      0.68      0.81        25
#             travel       0.62      0.93      0.74        40
#
#           accuracy                           0.80       204
#          macro avg       0.83      0.77      0.79       204
#       weighted avg       0.84      0.80      0.81       204

# %% [markdown]
# Код с этой же моделью, но без изменений логики, даёт f-score = 0.74.
#
# ~~Объявляю гойду!~~

# %%
UNLOAD_MODEL = False

if UNLOAD_MODEL:
    try:
        del LLM_PIPELINE
    except:
        pass

    from torch.cuda import empty_cache
    empty_cache()
    from gc import collect
    collect()
